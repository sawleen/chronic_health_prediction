# %% [markdown]
# # Model Training - By Member - Target : Allergic, Dermatitis, Asthma
# # (Group 2)
#
# Prepared by Tan Bee Hoon, modifed by LWL
#
# 16 Aug 2022
# 22 Aug 2022 : Modified from Model11 "3HiGrp1"
# 26 Aug 2022 : Add Tuned Parameters, Add Classification output

# %% [markdown]
# ## Import Library

# %%
# Need to revert to version 1.20.0 of numpy for Numba required by Shap
#!pip install numpy==1.20.0 --user

# %%
import random 
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import numpy as np 
from numpy import unique
from numpy import where

import pickle
from pandas import to_pickle
from pandas import read_pickle

import io
from datetime import date

from itertools import compress

# Libraries for Modelling
from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.svm import NuSVC
from sklearn.svm import SVC
from sklearn import tree
from sklearn.inspection import permutation_importance
from sklearn import metrics 
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_auc_score

from imblearn.over_sampling import SMOTE 

import shap

from xgboost import XGBClassifier

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Global Setting

# %% [markdown]
# ### Import File

# %%
TRAINING_FILE = "member_train_data_final.pkl"

# %% [markdown]
# ### Include Outlier Removal

# %%
INCL_IFOREST = 0

# %% [markdown]
# ### Include SMOTE

# %%
INCL_SMOTE = 0

# %%
# OVERSAMPLE_RATIO set here is to oversample the minority class with SMOTE 
# it corresponds to the desired ratio of
# number of samples in minority class over number of samples the majority class after resampling.
OVERSAMPLE_RATIO = 0.3

# %% [markdown]
# ### Adjust Train Test Ratio

# %%
# enter value 0<x<1 
TEST_SIZE = 0.3

# %% [markdown]
# ### Choose SelectFromModel Algo

# %%
# Choose either SVC or LR
SELECT_FR_MODEL_ALGO = "SVC"

# %% [markdown]
# ### Choose to run Shap or not

# %%
# Choose either 1 or 0, 1 to run shap explainer for Random Forest
RUN_SHAP = 1

# %% [markdown]
# ## Helper Function

# %%
def run_model_N_eval(X_train, X_test, y_train, y_test, model="RF"):
    if model == "RF":
        model_def = RandomForestClassifier(max_depth=15, min_samples_split=30, min_samples_leaf=1, \
                                           max_features="sqrt", random_state=42)
    elif model == "LR":
        model_def = LogisticRegression(random_state=42)
    elif model == "SVM":
        model_def = svm.SVC(C=1.0, kernel='linear', probability=True, random_state=42)
    elif model == "NLSVM":
        model_def = svm.SVC(C=2, kernel='rbf', probability=True, random_state=42)
    elif model == "XGB":
        model_def = XGBClassifier(max_depth=3, n_estimators=100, 
                                  reg_alpha=5, reg_lambda=5, gamma = 0, random_state=42)
    else:
        print("WRONG model type specified")
        return None
          
    # Pipeline
    if SELECT_FR_MODEL_ALGO == "SVC":
        clf = Pipeline([('feature_selection', SelectFromModel(LinearSVC(random_state=42))), 
                        ('clf', model_def)])
    elif SELECT_FR_MODEL_ALGO == "LR":
        clf = Pipeline([('feature_selection', SelectFromModel(LogisticRegression(random_state=42))), 
                        ('clf', model_def)])
    else:
        print("Please correct the decision for SELECT_FR_MODEL_ALGO, shd be either SVC or LR")
        
    # Fit Model
    clf.fit(X_train,y_train) 

    # Prediction
    predicted_test = clf.predict(X_test)
    predicted_train = clf.predict(X_train)
    
    # Generate Confusion Matrix
    cf_train_matrix = metrics.confusion_matrix(y_train, predicted_train)
    cf_test_matrix = metrics.confusion_matrix(y_test, predicted_test)
    
    print("Model: ", model, "\n")
    print("Labels:", y_train.unique(), "\n")
    
    print("\n","#"*100)

    print("For Training Data:")
    print(cf_train_matrix, "\n")
    # %matplotlib inline
    plt.figure(figsize=(10,8))
    sns.heatmap(cf_train_matrix, annot=True, fmt='d', vmin=0, vmax=y_train.shape[0]/len(y_train.unique()), cmap="Blues")
    plt.title("Training Data Confusion Matrix Heatmap")
    plt.xlabel('Predicted Labels')
    plt.ylabel('Actual Labels')
    plt.show()
    
    print(metrics.classification_report(y_train, predicted_train, digits=4, target_names=target_names), "\n" )
    
    report_dict_train = classification_report(y_train, predicted_train, output_dict=True)
    report_df_train = pd.DataFrame(report_dict_train)
    
    print("\n","#"*100)

    print("For Testing Data:")
    print(cf_test_matrix, "\n")
    # %matplotlib inline
    plt.figure(figsize=(10,8))
    sns.heatmap(cf_test_matrix, annot=True, fmt='d', vmin=0, vmax=y_test.shape[0]/len(y_train.unique()), cmap="Blues")
    plt.title("Testing Data Confusion Matrix Heatmap")
    plt.xlabel('Predicted Labels')
    plt.ylabel('Actual Labels')
    plt.show()
    
    print(metrics.classification_report(y_test, predicted_test,  digits=4, target_names=target_names), "\n" )
    
    report_dict_test = classification_report(y_test, predicted_test, output_dict=True)
    report_df_test = pd.DataFrame(report_dict_test)

    print("\n","#"*100)
    
    return clf.named_steps['clf'], clf.named_steps['feature_selection'], report_df_train, report_df_test

# %%
def make_shap_waterfall_plot(shap_values, features, feature_names, num_display=20):
    column_list = feature_names
    feature_ratio = (np.abs(shap_values).sum(0) / np.abs(shap_values).sum()) * 100
    column_list = column_list[np.argsort(feature_ratio)[::-1]]
    feature_ratio_order = np.sort(feature_ratio)[::-1]
    cum_sum = np.cumsum(feature_ratio_order)
    column_list = column_list[:num_display]
    feature_ratio_order = feature_ratio_order[:num_display]
    cum_sum = cum_sum[:num_display]
    
    num_height = 0
    if (num_display >= 20) & (len(column_list) >= 20):
        num_height = (len(column_list) - 20) * 0.4
        
    fig, ax1 = plt.subplots(figsize=(8, 8 + num_height))
    ax1.plot(cum_sum[::-1], column_list[::-1], c='blue', marker='o')
    ax2 = ax1.twiny()
    ax2.barh(column_list[::-1], feature_ratio_order[::-1], alpha=0.6)
    
    ax1.grid(True)
    ax2.grid(False)
    ax1.set_xticks(np.arange(0, round(cum_sum.max(), -1)+1, 10))
    ax2.set_xticks(np.arange(0, round(feature_ratio_order.max(), -1)+1, 10))
    ax1.set_xlabel('Cumulative Ratio')
    ax2.set_xlabel('Composition Ratio')
    ax1.tick_params(axis="y", labelsize=13)
    plt.ylim(-1, len(column_list))

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Import Training Data

# %%
# Check exported data
df = read_pickle(TRAINING_FILE)

# %%
drop_max = [col for col in df if col.startswith('MAX_')]

# %%
drop_min = [col for col in df if col.startswith('MIN_')]

# %%
# drop redundant variables
drop_list = ['FirstBookDate','LastBookDate', "WaviedCount_NA", 
             'Mode_consult_waived_reason', "Mode_consult_hr", 
             'CountVisit_chronic_list',
                "ConsultHr_0",
                "ConsultHr_8", 
                "ConsultHr_9",
                "ConsultHr_10",                 
                "ConsultHr_11",
                "ConsultHr_12",
                "ConsultHr_13",
                "ConsultHr_14",
                "ConsultHr_15",
                "ConsultHr_16",
                "ConsultHr_17",
                "ConsultHr_18",
                "ConsultHr_19",
                "ConsultHr_20",
                "ConsultHr_21",
                "ConsultHr_22",
                "ConsultHr_23"]

# %%
final_drop = drop_max + drop_min + drop_list

# %%
df.drop(final_drop, inplace = True, axis = 1)

# %%
pd.set_option('display.max_rows', None)
df.head(3).transpose()
# Out:
#                                                                                        0  \
# mem_id                                              0004A803-9EAB-4E3E-ACA6-F890F3805CFB
# gender                                                                            Female
# Mem_CountBooking                                                                       1
# AVE_mc_days                                                                            5
# AVE_count_diagnosis                                                                    1
# AVE_count_chronic                                                                      0
# AVE_count_medication                                                                   0
# AVE_count_repeatmed                                                                    0
# AVE_count_SymID                                                                        1
# age_yr                                                                                28
# WaviedCount_FOLLOW_UP                                                                  0
# WaviedCount_HEALTH_SCREENING_REVIEW                                                    0
# WaviedCount_OTHERS                                                                     0
# WaviedCount_REFERRAL                                                                   0
# WaviedCount_UNSUITABLE_FOR_TELECONSULT                                                 0
# WaviedCount_WHITECOAT_FAMILY                                                           0
# CountVisit_is_mc_issued                                                                1
# CountVisit_is_referral_letter_issued                                                   1
# CountVisit_Target_chronic                                                              0
# CountVisit_diag_H57                                                                    0
# CountVisit_diag_M23                                                                    0
# CountVisit_diag_T88                                                                    0
# CountVisit_diag_L20                                                                    0
# CountVisit_diag_R51                                                                    0
# CountVisit_diag_N94                                                                    0
# CountVisit_diag_G44                                                                    0
# CountVisit_diag_M79                                                                    0
# CountVisit_diag_J02                                                                    0
# CountVisit_diag_J06                                                                    1
# CountVisit_diag_G43                                                                    0
# CountVisit_diag_R21                                                                    0
# CountVisit_diag_M62                                                                    0
# CountVisit_diag_A09                                                                    0
# CountVisit_diag_J30                                                                    0
# CountVisit_diag_L30                                                                    0
# CountVisit_diag_T78                                                                    0
# CountVisit_diag_U07                                                                    0
# CountVisit_diag_K29                                                                    0
# CountVisit_diag_B35                                                                    0
# CountVisit_diag_K30                                                                    0
# CountVisit_diag_H81                                                                    0
# CountVisit_diag_N39                                                                    0
# CountVisit_diag_G47                                                                    0
# CountVisit_diag_Z76                                                                    0
# CountVisit_diag_K59                                                                    0
# CountVisit_diag_H10                                                                    0
# CountVisit_diag_R42                                                                    0
# CountVisit_diag_K21                                                                    0
# CountVisit_diag_S90                                                                    0
# CountVisit_diag_R50                                                                    0
# CountVisit_diag_U12                                                                    0
# CountVisit_diag_N92                                                                    0
# CountVisit_diag_M54                                                                    0
# CountVisit_diag_S60                                                                    0
# CountVisit_diag_I10                                                                    0
# CountVisit_diag_L03                                                                    0
# CountVisit_diag_K64                                                                    0
# CountVisit_diag_L98                                                                    0
# CountVisit_diag_B37                                                                    0
# CountVisit_diag_L73                                                                    0
# CountVisit_diag_H00                                                                    0
# CountVisit_diag_N76                                                                    0
# CountVisit_diag_J01                                                                    0
# CountVisit_diag_J45                                                                    0
# CountVisit_diag_E78                                                                    0
# CountVisit_diag_L02                                                                    0
# CountVisit_diag_R52                                                                    0
# CountVisit_diag_K12                                                                    0
# CountVisit_diag_K58                                                                    0
# CountVisit_diag_K07                                                                    0
# CountVisit_diag_L70                                                                    0
# CountVisit_diag_Z71                                                                    0
# CountVisit_diag_S63                                                                    0
# CountVisit_diag_M25                                                                    0
# CountVisit_diag_K05                                                                    0
# CountVisit_diag_E03                                                                    0
# CountVisit_diag_L50                                                                    0
# CountVisit_diag_W57                                                                    0
# CountVisit_diag_H93                                                                    0
# CountVisit_diag_H01                                                                    0
# CountVisit_diag_E11                                                                    0
# CountVisit_diag_S13                                                                    0
# CountVisit_diag_F41                                                                    0
# CountVisit_diag_R53                                                                    0
# CountVisit_diag_O91                                                                    0
# CountVisit_diag_H02                                                                    0
# CountVisit_diag_R11                                                                    0
# CountVisit_diag_S93                                                                    0
# CountVisit_diag_L24                                                                    0
# CountVisit_diag_J39                                                                    0
# CountVisit_diag_J32                                                                    0
# CountVisit_diag_B00                                                                    0
# CountVisit_diag_L64                                                                    0
# CountVisit_diag_Y42                                                                    0
# CountVisit_diag_R10                                                                    0
# CountVisit_diag_M10                                                                    0
# CountVisit_diag_M75                                                                    0
# CountVisit_diag_Z02                                                                    0
# CountVisit_diag_J03                                                                    0
# CountVisit_diag_R07                                                                    0
# CountVisit_diag_K13                                                                    0
# CountVisit_diag_Z30                                                                    0
# CountVisit_diag_P39                                                                    0
# CountVisit_diag_R22                                                                    0
# CountVisit_diag_H60                                                                    0
# CountVisit_diag_B02                                                                    0
# CountVisit_diag_L29                                                                    0
# CountVisit_diag_E05                                                                    0
# CountVisit_diag_N64                                                                    0
# CountVisit_diag_R05                                                                    0
# CountVisit_diag_L60                                                                    0
# CountVisit_diag_S80                                                                    0
# CountVisit_diag_M65                                                                    0
# CountVisit_diag_J22                                                                    0
# CountVisit_diag_O21                                                                    0
# CountVisit_diag_M72                                                                    0
# CountVisit_diag_L23                                                                    0
# CountVisit_diag_K52                                                                    0
# CountVisit_chronic_NoneChronic                                                         1
# CountVisit_chronic_Atopic_dermatitis                                                   0
# CountVisit_chronic_Migraine                                                            0
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis                                     0
# CountVisit_chronic_Gastro-oesophageal_reflux_di...                                     0
# CountVisit_chronic_Hypertension                                                        0
# CountVisit_chronic_Asthma                                                              0
# CountVisit_chronic_Hyperlipidaemia                                                     0
# CountVisit_chronic_Thyroid                                                             0
# CountVisit_chronic_Diabetes                                                            0
# CountVisit_chronic_Gout                                                                0
# CountVisit_symp_others                                                                 1
# CountVisit_symp_medical_referral                                                       0
# CountVisit_symp_headache                                                               0
# CountVisit_symp_giddiness                                                              0
# CountVisit_symp_fever                                                                  0
# CountVisit_symp_N                                                                      0
# CountVisit_symp_cold_sores                                                             0
# CountVisit_symp_rash                                                                   0
# CountVisit_symp_sore_throat                                                            0
# CountVisit_symp_flu                                                                    0
# CountVisit_symp_cough                                                                  0
# CountVisit_symp_cold                                                                   0
# CountVisit_symp_vomiting                                                               0
# CountVisit_symp_diarrhoea                                                              0
# CountVisit_symp_chronic_medicine_top-up                                                0
# CountVisit_symp_chronic_illness_management                                             0
# CountVisit_symp_discuss_lab_results                                                    0
# DiffDays_Vist                                                                          0
# Ave_VisitGapDays                                                                       0
# Target_Chronic                                                                         0
# Target_Dermatitis                                                                      0
# Target_Migraine                                                                        0
# Target_Allergic                                                                        0
# Target_Gastro                                                                          0
# Target_Hypertension                                                                    0
# Target_Asthma                                                                          0
# Target_Hyperlipidaemia                                                                 0
# Target_Thyroid                                                                         0
# Target_Diabetes                                                                        0
# Target_Gout                                                                            0
# Target_3High                                                                           0
# Target_Allergic_Dermatitis_Asthma                                                      0
# Target_Migraine_Gastro_Thyroid_Gout                                                    0
# ConsultHr_8to10                                                                        0
# ConsultHr_11to13                                                                       1
# ConsultHr_14to17                                                                       0
# ConsultHr_18to21                                                                       0
# ConsultHr_22to23                                                                       0
# Prin1_sym_common                                                               -1.082006
# Prin2_sym_rash                                                                 -0.399412
# Prin3_sym_headache                                                              -0.71159
# Prin4_sym_diarrhea                                                              0.042277
#
#                                                                                        1  \
# mem_id                                              001205F3-C949-4A64-B7D8-8BB38201627C
# gender                                                                            Female
# Mem_CountBooking                                                                       2
# AVE_mc_days                                                                            0
# AVE_count_diagnosis                                                                    1
# AVE_count_chronic                                                                      0
# AVE_count_medication                                                                   1
# AVE_count_repeatmed                                                                    0
# AVE_count_SymID                                                                        1
# age_yr                                                                                50
# WaviedCount_FOLLOW_UP                                                                  0
# WaviedCount_HEALTH_SCREENING_REVIEW                                                    0
# WaviedCount_OTHERS                                                                     0
# WaviedCount_REFERRAL                                                                   0
# WaviedCount_UNSUITABLE_FOR_TELECONSULT                                                 0
# WaviedCount_WHITECOAT_FAMILY                                                           0
# CountVisit_is_mc_issued                                                                0
# CountVisit_is_referral_letter_issued                                                   1
# CountVisit_Target_chronic                                                              1
# CountVisit_diag_H57                                                                    0
# CountVisit_diag_M23                                                                    0
# CountVisit_diag_T88                                                                    0
# CountVisit_diag_L20                                                                    0
# CountVisit_diag_R51                                                                    0
# CountVisit_diag_N94                                                                    0
# CountVisit_diag_G44                                                                    0
# CountVisit_diag_M79                                                                    0
# CountVisit_diag_J02                                                                    0
# CountVisit_diag_J06                                                                    0
# CountVisit_diag_G43                                                                    0
# CountVisit_diag_R21                                                                    0
# CountVisit_diag_M62                                                                    0
# CountVisit_diag_A09                                                                    0
# CountVisit_diag_J30                                                                    0
# CountVisit_diag_L30                                                                    0
# CountVisit_diag_T78                                                                    0
# CountVisit_diag_U07                                                                    0
# CountVisit_diag_K29                                                                    0
# CountVisit_diag_B35                                                                    0
# CountVisit_diag_K30                                                                    0
# CountVisit_diag_H81                                                                    0
# CountVisit_diag_N39                                                                    0
# CountVisit_diag_G47                                                                    0
# CountVisit_diag_Z76                                                                    0
# CountVisit_diag_K59                                                                    0
# CountVisit_diag_H10                                                                    0
# CountVisit_diag_R42                                                                    0
# CountVisit_diag_K21                                                                    0
# CountVisit_diag_S90                                                                    0
# CountVisit_diag_R50                                                                    0
# CountVisit_diag_U12                                                                    0
# CountVisit_diag_N92                                                                    0
# CountVisit_diag_M54                                                                    0
# CountVisit_diag_S60                                                                    0
# CountVisit_diag_I10                                                                    1
# CountVisit_diag_L03                                                                    0
# CountVisit_diag_K64                                                                    0
# CountVisit_diag_L98                                                                    0
# CountVisit_diag_B37                                                                    0
# CountVisit_diag_L73                                                                    0
# CountVisit_diag_H00                                                                    0
# CountVisit_diag_N76                                                                    0
# CountVisit_diag_J01                                                                    0
# CountVisit_diag_J45                                                                    0
# CountVisit_diag_E78                                                                    0
# CountVisit_diag_L02                                                                    0
# CountVisit_diag_R52                                                                    0
# CountVisit_diag_K12                                                                    0
# CountVisit_diag_K58                                                                    0
# CountVisit_diag_K07                                                                    0
# CountVisit_diag_L70                                                                    0
# CountVisit_diag_Z71                                                                    0
# CountVisit_diag_S63                                                                    0
# CountVisit_diag_M25                                                                    0
# CountVisit_diag_K05                                                                    0
# CountVisit_diag_E03                                                                    0
# CountVisit_diag_L50                                                                    0
# CountVisit_diag_W57                                                                    0
# CountVisit_diag_H93                                                                    0
# CountVisit_diag_H01                                                                    0
# CountVisit_diag_E11                                                                    0
# CountVisit_diag_S13                                                                    0
# CountVisit_diag_F41                                                                    0
# CountVisit_diag_R53                                                                    0
# CountVisit_diag_O91                                                                    0
# CountVisit_diag_H02                                                                    0
# CountVisit_diag_R11                                                                    0
# CountVisit_diag_S93                                                                    0
# CountVisit_diag_L24                                                                    0
# CountVisit_diag_J39                                                                    0
# CountVisit_diag_J32                                                                    0
# CountVisit_diag_B00                                                                    0
# CountVisit_diag_L64                                                                    0
# CountVisit_diag_Y42                                                                    0
# CountVisit_diag_R10                                                                    0
# CountVisit_diag_M10                                                                    0
# CountVisit_diag_M75                                                                    0
# CountVisit_diag_Z02                                                                    0
# CountVisit_diag_J03                                                                    0
# CountVisit_diag_R07                                                                    0
# CountVisit_diag_K13                                                                    0
# CountVisit_diag_Z30                                                                    0
# CountVisit_diag_P39                                                                    0
# CountVisit_diag_R22                                                                    0
# CountVisit_diag_H60                                                                    0
# CountVisit_diag_B02                                                                    0
# CountVisit_diag_L29                                                                    0
# CountVisit_diag_E05                                                                    0
# CountVisit_diag_N64                                                                    0
# CountVisit_diag_R05                                                                    0
# CountVisit_diag_L60                                                                    0
# CountVisit_diag_S80                                                                    0
# CountVisit_diag_M65                                                                    0
# CountVisit_diag_J22                                                                    0
# CountVisit_diag_O21                                                                    0
# CountVisit_diag_M72                                                                    0
# CountVisit_diag_L23                                                                    0
# CountVisit_diag_K52                                                                    0
# CountVisit_chronic_NoneChronic                                                         1
# CountVisit_chronic_Atopic_dermatitis                                                   0
# CountVisit_chronic_Migraine                                                            0
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis                                     0
# CountVisit_chronic_Gastro-oesophageal_reflux_di...                                     0
# CountVisit_chronic_Hypertension                                                        1
# CountVisit_chronic_Asthma                                                              0
# CountVisit_chronic_Hyperlipidaemia                                                     0
# CountVisit_chronic_Thyroid                                                             0
# CountVisit_chronic_Diabetes                                                            0
# CountVisit_chronic_Gout                                                                0
# CountVisit_symp_others                                                                 1
# CountVisit_symp_medical_referral                                                       1
# CountVisit_symp_headache                                                               0
# CountVisit_symp_giddiness                                                              0
# CountVisit_symp_fever                                                                  0
# CountVisit_symp_N                                                                      0
# CountVisit_symp_cold_sores                                                             0
# CountVisit_symp_rash                                                                   0
# CountVisit_symp_sore_throat                                                            0
# CountVisit_symp_flu                                                                    0
# CountVisit_symp_cough                                                                  0
# CountVisit_symp_cold                                                                   0
# CountVisit_symp_vomiting                                                               0
# CountVisit_symp_diarrhoea                                                              0
# CountVisit_symp_chronic_medicine_top-up                                                1
# CountVisit_symp_chronic_illness_management                                             0
# CountVisit_symp_discuss_lab_results                                                    0
# DiffDays_Vist                                                                         16
# Ave_VisitGapDays                                                                       8
# Target_Chronic                                                                         1
# Target_Dermatitis                                                                      0
# Target_Migraine                                                                        0
# Target_Allergic                                                                        0
# Target_Gastro                                                                          0
# Target_Hypertension                                                                    1
# Target_Asthma                                                                          0
# Target_Hyperlipidaemia                                                                 0
# Target_Thyroid                                                                         0
# Target_Diabetes                                                                        0
# Target_Gout                                                                            0
# Target_3High                                                                           1
# Target_Allergic_Dermatitis_Asthma                                                      0
# Target_Migraine_Gastro_Thyroid_Gout                                                    0
# ConsultHr_8to10                                                                        1
# ConsultHr_11to13                                                                       0
# ConsultHr_14to17                                                                       0
# ConsultHr_18to21                                                                       1
# ConsultHr_22to23                                                                       0
# Prin1_sym_common                                                               -1.082006
# Prin2_sym_rash                                                                 -0.399412
# Prin3_sym_headache                                                              -0.71159
# Prin4_sym_diarrhea                                                              0.042277
#
#                                                                                        2
# mem_id                                              0012A643-20F7-46B7-8A9E-9063E7A5CAA9
# gender                                                                            Female
# Mem_CountBooking                                                                       1
# AVE_mc_days                                                                            5
# AVE_count_diagnosis                                                                    1
# AVE_count_chronic                                                                      0
# AVE_count_medication                                                                   2
# AVE_count_repeatmed                                                                    1
# AVE_count_SymID                                                                        4
# age_yr                                                                                32
# WaviedCount_FOLLOW_UP                                                                  0
# WaviedCount_HEALTH_SCREENING_REVIEW                                                    0
# WaviedCount_OTHERS                                                                     0
# WaviedCount_REFERRAL                                                                   0
# WaviedCount_UNSUITABLE_FOR_TELECONSULT                                                 0
# WaviedCount_WHITECOAT_FAMILY                                                           0
# CountVisit_is_mc_issued                                                                1
# CountVisit_is_referral_letter_issued                                                   0
# CountVisit_Target_chronic                                                              0
# CountVisit_diag_H57                                                                    0
# CountVisit_diag_M23                                                                    0
# CountVisit_diag_T88                                                                    0
# CountVisit_diag_L20                                                                    0
# CountVisit_diag_R51                                                                    0
# CountVisit_diag_N94                                                                    0
# CountVisit_diag_G44                                                                    0
# CountVisit_diag_M79                                                                    0
# CountVisit_diag_J02                                                                    0
# CountVisit_diag_J06                                                                    1
# CountVisit_diag_G43                                                                    0
# CountVisit_diag_R21                                                                    0
# CountVisit_diag_M62                                                                    0
# CountVisit_diag_A09                                                                    0
# CountVisit_diag_J30                                                                    0
# CountVisit_diag_L30                                                                    0
# CountVisit_diag_T78                                                                    0
# CountVisit_diag_U07                                                                    0
# CountVisit_diag_K29                                                                    0
# CountVisit_diag_B35                                                                    0
# CountVisit_diag_K30                                                                    0
# CountVisit_diag_H81                                                                    0
# CountVisit_diag_N39                                                                    0
# CountVisit_diag_G47                                                                    0
# CountVisit_diag_Z76                                                                    0
# CountVisit_diag_K59                                                                    0
# CountVisit_diag_H10                                                                    0
# CountVisit_diag_R42                                                                    0
# CountVisit_diag_K21                                                                    0
# CountVisit_diag_S90                                                                    0
# CountVisit_diag_R50                                                                    0
# CountVisit_diag_U12                                                                    0
# CountVisit_diag_N92                                                                    0
# CountVisit_diag_M54                                                                    0
# CountVisit_diag_S60                                                                    0
# CountVisit_diag_I10                                                                    0
# CountVisit_diag_L03                                                                    0
# CountVisit_diag_K64                                                                    0
# CountVisit_diag_L98                                                                    0
# CountVisit_diag_B37                                                                    0
# CountVisit_diag_L73                                                                    0
# CountVisit_diag_H00                                                                    0
# CountVisit_diag_N76                                                                    0
# CountVisit_diag_J01                                                                    0
# CountVisit_diag_J45                                                                    0
# CountVisit_diag_E78                                                                    0
# CountVisit_diag_L02                                                                    0
# CountVisit_diag_R52                                                                    0
# CountVisit_diag_K12                                                                    0
# CountVisit_diag_K58                                                                    0
# CountVisit_diag_K07                                                                    0
# CountVisit_diag_L70                                                                    0
# CountVisit_diag_Z71                                                                    0
# CountVisit_diag_S63                                                                    0
# CountVisit_diag_M25                                                                    0
# CountVisit_diag_K05                                                                    0
# CountVisit_diag_E03                                                                    0
# CountVisit_diag_L50                                                                    0
# CountVisit_diag_W57                                                                    0
# CountVisit_diag_H93                                                                    0
# CountVisit_diag_H01                                                                    0
# CountVisit_diag_E11                                                                    0
# CountVisit_diag_S13                                                                    0
# CountVisit_diag_F41                                                                    0
# CountVisit_diag_R53                                                                    0
# CountVisit_diag_O91                                                                    0
# CountVisit_diag_H02                                                                    0
# CountVisit_diag_R11                                                                    0
# CountVisit_diag_S93                                                                    0
# CountVisit_diag_L24                                                                    0
# CountVisit_diag_J39                                                                    0
# CountVisit_diag_J32                                                                    0
# CountVisit_diag_B00                                                                    0
# CountVisit_diag_L64                                                                    0
# CountVisit_diag_Y42                                                                    0
# CountVisit_diag_R10                                                                    0
# CountVisit_diag_M10                                                                    0
# CountVisit_diag_M75                                                                    0
# CountVisit_diag_Z02                                                                    0
# CountVisit_diag_J03                                                                    0
# CountVisit_diag_R07                                                                    0
# CountVisit_diag_K13                                                                    0
# CountVisit_diag_Z30                                                                    0
# CountVisit_diag_P39                                                                    0
# CountVisit_diag_R22                                                                    0
# CountVisit_diag_H60                                                                    0
# CountVisit_diag_B02                                                                    0
# CountVisit_diag_L29                                                                    0
# CountVisit_diag_E05                                                                    0
# CountVisit_diag_N64                                                                    0
# CountVisit_diag_R05                                                                    0
# CountVisit_diag_L60                                                                    0
# CountVisit_diag_S80                                                                    0
# CountVisit_diag_M65                                                                    0
# CountVisit_diag_J22                                                                    0
# CountVisit_diag_O21                                                                    0
# CountVisit_diag_M72                                                                    0
# CountVisit_diag_L23                                                                    0
# CountVisit_diag_K52                                                                    0
# CountVisit_chronic_NoneChronic                                                         1
# CountVisit_chronic_Atopic_dermatitis                                                   0
# CountVisit_chronic_Migraine                                                            0
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis                                     0
# CountVisit_chronic_Gastro-oesophageal_reflux_di...                                     0
# CountVisit_chronic_Hypertension                                                        0
# CountVisit_chronic_Asthma                                                              0
# CountVisit_chronic_Hyperlipidaemia                                                     0
# CountVisit_chronic_Thyroid                                                             0
# CountVisit_chronic_Diabetes                                                            0
# CountVisit_chronic_Gout                                                                0
# CountVisit_symp_others                                                                 0
# CountVisit_symp_medical_referral                                                       0
# CountVisit_symp_headache                                                               0
# CountVisit_symp_giddiness                                                              0
# CountVisit_symp_fever                                                                  0
# CountVisit_symp_N                                                                      0
# CountVisit_symp_cold_sores                                                             0
# CountVisit_symp_rash                                                                   0
# CountVisit_symp_sore_throat                                                            1
# CountVisit_symp_flu                                                                    1
# CountVisit_symp_cough                                                                  1
# CountVisit_symp_cold                                                                   1
# CountVisit_symp_vomiting                                                               0
# CountVisit_symp_diarrhoea                                                              0
# CountVisit_symp_chronic_medicine_top-up                                                0
# CountVisit_symp_chronic_illness_management                                             0
# CountVisit_symp_discuss_lab_results                                                    0
# DiffDays_Vist                                                                          0
# Ave_VisitGapDays                                                                       0
# Target_Chronic                                                                         0
# Target_Dermatitis                                                                      0
# Target_Migraine                                                                        0
# Target_Allergic                                                                        0
# Target_Gastro                                                                          0
# Target_Hypertension                                                                    0
# Target_Asthma                                                                          0
# Target_Hyperlipidaemia                                                                 0
# Target_Thyroid                                                                         0
# Target_Diabetes                                                                        0
# Target_Gout                                                                            0
# Target_3High                                                                           0
# Target_Allergic_Dermatitis_Asthma                                                      0
# Target_Migraine_Gastro_Thyroid_Gout                                                    0
# ConsultHr_8to10                                                                        1
# ConsultHr_11to13                                                                       0
# ConsultHr_14to17                                                                       0
# ConsultHr_18to21                                                                       0
# ConsultHr_22to23                                                                       0
# Prin1_sym_common                                                                2.543257
# Prin2_sym_rash                                                                 -1.661338
# Prin3_sym_headache                                                              -0.99956
# Prin4_sym_diarrhea                                                              0.257462

# %%
print("Shape of data: ", df.shape)
# Out:
# Shape of data:  (5000, 171)

# %% [markdown]
# ## Basic Training Data Investigation¶

# %%
print("Basic Data structure Info")
df.info("deep")
# Out:
# Basic Data structure Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 171 columns):
#  #    Column                                                Dtype
# ---   ------                                                -----
#  0    mem_id                                                object
#  1    gender                                                object
#  2    Mem_CountBooking                                      int64
#  3    AVE_mc_days                                           int64
#  4    AVE_count_diagnosis                                   int64
#  5    AVE_count_chronic                                     int64
#  6    AVE_count_medication                                  int64
#  7    AVE_count_repeatmed                                   int64
#  8    AVE_count_SymID                                       int64
#  9    age_yr                                                int64
#  10   WaviedCount_FOLLOW_UP                                 int64
#  11   WaviedCount_HEALTH_SCREENING_REVIEW                   int64
#  12   WaviedCount_OTHERS                                    int64
#  13   WaviedCount_REFERRAL                                  int64
#  14   WaviedCount_UNSUITABLE_FOR_TELECONSULT                int64
#  15   WaviedCount_WHITECOAT_FAMILY                          int64
#  16   CountVisit_is_mc_issued                               int32
#  17   CountVisit_is_referral_letter_issued                  int32
#  18   CountVisit_Target_chronic                             int32
#  19   CountVisit_diag_H57                                   int32
#  20   CountVisit_diag_M23                                   int32
#  21   CountVisit_diag_T88                                   int32
#  22   CountVisit_diag_L20                                   int32
#  23   CountVisit_diag_R51                                   int32
#  24   CountVisit_diag_N94                                   int32
#  25   CountVisit_diag_G44                                   int32
#  26   CountVisit_diag_M79                                   int32
#  27   CountVisit_diag_J02                                   int32
#  28   CountVisit_diag_J06                                   int32
#  29   CountVisit_diag_G43                                   int32
#  30   CountVisit_diag_R21                                   int32
#  31   CountVisit_diag_M62                                   int32
#  32   CountVisit_diag_A09                                   int32
#  33   CountVisit_diag_J30                                   int32
#  34   CountVisit_diag_L30                                   int32
#  35   CountVisit_diag_T78                                   int32
#  36   CountVisit_diag_U07                                   int32
#  37   CountVisit_diag_K29                                   int32
#  38   CountVisit_diag_B35                                   int32
#  39   CountVisit_diag_K30                                   int32
#  40   CountVisit_diag_H81                                   int32
#  41   CountVisit_diag_N39                                   int32
#  42   CountVisit_diag_G47                                   int32
#  43   CountVisit_diag_Z76                                   int32
#  44   CountVisit_diag_K59                                   int32
#  45   CountVisit_diag_H10                                   int32
#  46   CountVisit_diag_R42                                   int32
#  47   CountVisit_diag_K21                                   int32
#  48   CountVisit_diag_S90                                   int32
#  49   CountVisit_diag_R50                                   int32
#  50   CountVisit_diag_U12                                   int32
#  51   CountVisit_diag_N92                                   int32
#  52   CountVisit_diag_M54                                   int32
#  53   CountVisit_diag_S60                                   int32
#  54   CountVisit_diag_I10                                   int32
#  55   CountVisit_diag_L03                                   int32
#  56   CountVisit_diag_K64                                   int32
#  57   CountVisit_diag_L98                                   int32
#  58   CountVisit_diag_B37                                   int32
#  59   CountVisit_diag_L73                                   int32
#  60   CountVisit_diag_H00                                   int32
#  61   CountVisit_diag_N76                                   int32
#  62   CountVisit_diag_J01                                   int32
#  63   CountVisit_diag_J45                                   int32
#  64   CountVisit_diag_E78                                   int32
#  65   CountVisit_diag_L02                                   int32
#  66   CountVisit_diag_R52                                   int32
#  67   CountVisit_diag_K12                                   int32
#  68   CountVisit_diag_K58                                   int32
#  69   CountVisit_diag_K07                                   int32
#  70   CountVisit_diag_L70                                   int32
#  71   CountVisit_diag_Z71                                   int32
#  72   CountVisit_diag_S63                                   int32
#  73   CountVisit_diag_M25                                   int32
#  74   CountVisit_diag_K05                                   int32
#  75   CountVisit_diag_E03                                   int32
#  76   CountVisit_diag_L50                                   int32
#  77   CountVisit_diag_W57                                   int32
#  78   CountVisit_diag_H93                                   int32
#  79   CountVisit_diag_H01                                   int32
#  80   CountVisit_diag_E11                                   int32
#  81   CountVisit_diag_S13                                   int32
#  82   CountVisit_diag_F41                                   int32
#  83   CountVisit_diag_R53                                   int32
#  84   CountVisit_diag_O91                                   int32
#  85   CountVisit_diag_H02                                   int32
#  86   CountVisit_diag_R11                                   int32
#  87   CountVisit_diag_S93                                   int32
#  88   CountVisit_diag_L24                                   int32
#  89   CountVisit_diag_J39                                   int32
#  90   CountVisit_diag_J32                                   int32
#  91   CountVisit_diag_B00                                   int32
#  92   CountVisit_diag_L64                                   int32
#  93   CountVisit_diag_Y42                                   int32
#  94   CountVisit_diag_R10                                   int32
#  95   CountVisit_diag_M10                                   int32
#  96   CountVisit_diag_M75                                   int32
#  97   CountVisit_diag_Z02                                   int32
#  98   CountVisit_diag_J03                                   int32
#  99   CountVisit_diag_R07                                   int32
#  100  CountVisit_diag_K13                                   int32
#  101  CountVisit_diag_Z30                                   int32
#  102  CountVisit_diag_P39                                   int32
#  103  CountVisit_diag_R22                                   int32
#  104  CountVisit_diag_H60                                   int32
#  105  CountVisit_diag_B02                                   int32
#  106  CountVisit_diag_L29                                   int32
#  107  CountVisit_diag_E05                                   int32
#  108  CountVisit_diag_N64                                   int32
#  109  CountVisit_diag_R05                                   int32
#  110  CountVisit_diag_L60                                   int32
#  111  CountVisit_diag_S80                                   int32
#  112  CountVisit_diag_M65                                   int32
#  113  CountVisit_diag_J22                                   int32
#  114  CountVisit_diag_O21                                   int32
#  115  CountVisit_diag_M72                                   int32
#  116  CountVisit_diag_L23                                   int32
#  117  CountVisit_diag_K52                                   int32
#  118  CountVisit_chronic_NoneChronic                        int32
#  119  CountVisit_chronic_Atopic_dermatitis                  int32
#  120  CountVisit_chronic_Migraine                           int32
#  121  CountVisit_chronic_Vasomotor_and_allergic_rhinitis    int32
#  122  CountVisit_chronic_Gastro-oesophageal_reflux_disease  int32
#  123  CountVisit_chronic_Hypertension                       int32
#  124  CountVisit_chronic_Asthma                             int32
#  125  CountVisit_chronic_Hyperlipidaemia                    int32
#  126  CountVisit_chronic_Thyroid                            int32
#  127  CountVisit_chronic_Diabetes                           int32
#  128  CountVisit_chronic_Gout                               int32
#  129  CountVisit_symp_others                                int32
#  130  CountVisit_symp_medical_referral                      int32
#  131  CountVisit_symp_headache                              int32
#  132  CountVisit_symp_giddiness                             int32
#  133  CountVisit_symp_fever                                 int32
#  134  CountVisit_symp_N                                     int32
#  135  CountVisit_symp_cold_sores                            int32
#  136  CountVisit_symp_rash                                  int32
#  137  CountVisit_symp_sore_throat                           int32
#  138  CountVisit_symp_flu                                   int32
#  139  CountVisit_symp_cough                                 int32
#  140  CountVisit_symp_cold                                  int32
#  141  CountVisit_symp_vomiting                              int32
#  142  CountVisit_symp_diarrhoea                             int32
#  143  CountVisit_symp_chronic_medicine_top-up               int32
#  144  CountVisit_symp_chronic_illness_management            int32
#  145  CountVisit_symp_discuss_lab_results                   int32
#  146  DiffDays_Vist                                         int64
#  147  Ave_VisitGapDays                                      int64
#  148  Target_Chronic                                        int64
#  149  Target_Dermatitis                                     int64
#  150  Target_Migraine                                       int64
#  151  Target_Allergic                                       int64
#  152  Target_Gastro                                         int64
#  153  Target_Hypertension                                   int64
#  154  Target_Asthma                                         int64
#  155  Target_Hyperlipidaemia                                int64
#  156  Target_Thyroid                                        int64
#  157  Target_Diabetes                                       int64
#  158  Target_Gout                                           int64
#  159  Target_3High                                          int64
#  160  Target_Allergic_Dermatitis_Asthma                     int64
#  161  Target_Migraine_Gastro_Thyroid_Gout                   int64
#  162  ConsultHr_8to10                                       int64
#  163  ConsultHr_11to13                                      int64
#  164  ConsultHr_14to17                                      int64
#  165  ConsultHr_18to21                                      int64
#  166  ConsultHr_22to23                                      int64
#  167  Prin1_sym_common                                      float64
#  168  Prin2_sym_rash                                        float64
#  169  Prin3_sym_headache                                    float64
#  170  Prin4_sym_diarrhea                                    float64
# dtypes: float64(4), int32(130), int64(35), object(2)
# memory usage: 4.1+ MB

# %%
print("Basic Data Summary")
df.describe().transpose()
# Out:
# Basic Data Summary
#                                                      count          mean  \
# Mem_CountBooking                                    5000.0  2.044200e+00
# AVE_mc_days                                         5000.0  9.592000e-01
# AVE_count_diagnosis                                 5000.0  1.132400e+00
# AVE_count_chronic                                   5000.0  8.820000e-02
# AVE_count_medication                                5000.0  1.805600e+00
# AVE_count_repeatmed                                 5000.0  6.926000e-01
# AVE_count_SymID                                     5000.0  1.740400e+00
# age_yr                                              5000.0  3.601020e+01
# WaviedCount_FOLLOW_UP                               5000.0  3.900000e-02
# WaviedCount_HEALTH_SCREENING_REVIEW                 5000.0  3.520000e-02
# WaviedCount_OTHERS                                  5000.0  1.500000e-02
# WaviedCount_REFERRAL                                5000.0  6.000000e-04
# WaviedCount_UNSUITABLE_FOR_TELECONSULT              5000.0  9.000000e-03
# WaviedCount_WHITECOAT_FAMILY                        5000.0  3.000000e-03
# CountVisit_is_mc_issued                             5000.0  1.167600e+00
# CountVisit_is_referral_letter_issued                5000.0  1.388000e-01
# CountVisit_Target_chronic                           5000.0  2.974000e-01
# CountVisit_diag_H57                                 5000.0  2.580000e-02
# CountVisit_diag_M23                                 5000.0  4.200000e-03
# CountVisit_diag_T88                                 5000.0  1.006000e-01
# CountVisit_diag_L20                                 5000.0  3.900000e-02
# CountVisit_diag_R51                                 5000.0  2.434000e-01
# CountVisit_diag_N94                                 5000.0  1.132000e-01
# CountVisit_diag_G44                                 5000.0  6.440000e-02
# CountVisit_diag_M79                                 5000.0  7.540000e-02
# CountVisit_diag_J02                                 5000.0  1.960000e-02
# CountVisit_diag_J06                                 5000.0  1.668000e-01
# CountVisit_diag_G43                                 5000.0  3.800000e-02
# CountVisit_diag_R21                                 5000.0  5.900000e-02
# CountVisit_diag_M62                                 5000.0  6.380000e-02
# CountVisit_diag_A09                                 5000.0  2.334000e-01
# CountVisit_diag_J30                                 5000.0  7.640000e-02
# CountVisit_diag_L30                                 5000.0  1.860000e-02
# CountVisit_diag_T78                                 5000.0  1.840000e-02
# CountVisit_diag_U07                                 5000.0  2.840000e-02
# CountVisit_diag_K29                                 5000.0  6.340000e-02
# CountVisit_diag_B35                                 5000.0  2.400000e-02
# CountVisit_diag_K30                                 5000.0  3.540000e-02
# CountVisit_diag_H81                                 5000.0  1.700000e-02
# CountVisit_diag_N39                                 5000.0  4.300000e-02
# CountVisit_diag_G47                                 5000.0  1.380000e-02
# CountVisit_diag_Z76                                 5000.0  1.620000e-02
# CountVisit_diag_K59                                 5000.0  2.260000e-02
# CountVisit_diag_H10                                 5000.0  2.600000e-02
# CountVisit_diag_R42                                 5000.0  2.460000e-02
# CountVisit_diag_K21                                 5000.0  4.000000e-02
# CountVisit_diag_S90                                 5000.0  4.600000e-03
# CountVisit_diag_R50                                 5000.0  4.000000e-02
# CountVisit_diag_U12                                 5000.0  1.620000e-02
# CountVisit_diag_N92                                 5000.0  7.600000e-03
# CountVisit_diag_M54                                 5000.0  5.580000e-02
# CountVisit_diag_S60                                 5000.0  2.800000e-03
# CountVisit_diag_I10                                 5000.0  4.780000e-02
# CountVisit_diag_L03                                 5000.0  1.040000e-02
# CountVisit_diag_K64                                 5000.0  9.600000e-03
# CountVisit_diag_L98                                 5000.0  1.140000e-02
# CountVisit_diag_B37                                 5000.0  1.460000e-02
# CountVisit_diag_L73                                 5000.0  2.800000e-03
# CountVisit_diag_H00                                 5000.0  2.600000e-02
# CountVisit_diag_N76                                 5000.0  7.800000e-03
# CountVisit_diag_J01                                 5000.0  8.200000e-03
# CountVisit_diag_J45                                 5000.0  2.960000e-02
# CountVisit_diag_E78                                 5000.0  3.540000e-02
# CountVisit_diag_L02                                 5000.0  7.800000e-03
# CountVisit_diag_R52                                 5000.0  5.000000e-03
# CountVisit_diag_K12                                 5000.0  1.080000e-02
# CountVisit_diag_K58                                 5000.0  6.200000e-03
# CountVisit_diag_K07                                 5000.0  2.800000e-03
# CountVisit_diag_L70                                 5000.0  4.200000e-03
# CountVisit_diag_Z71                                 5000.0  3.500000e-02
# CountVisit_diag_S63                                 5000.0  3.600000e-03
# CountVisit_diag_M25                                 5000.0  1.000000e-02
# CountVisit_diag_K05                                 5000.0  3.200000e-03
# CountVisit_diag_E03                                 5000.0  6.200000e-03
# CountVisit_diag_L50                                 5000.0  1.760000e-02
# CountVisit_diag_W57                                 5000.0  6.600000e-03
# CountVisit_diag_H93                                 5000.0  3.000000e-03
# CountVisit_diag_H01                                 5000.0  1.000000e-02
# CountVisit_diag_E11                                 5000.0  1.180000e-02
# CountVisit_diag_S13                                 5000.0  3.200000e-03
# CountVisit_diag_F41                                 5000.0  3.800000e-03
# CountVisit_diag_R53                                 5000.0  1.400000e-02
# CountVisit_diag_O91                                 5000.0  2.400000e-03
# CountVisit_diag_H02                                 5000.0  4.600000e-03
# CountVisit_diag_R11                                 5000.0  1.940000e-02
# CountVisit_diag_S93                                 5000.0  6.000000e-03
# CountVisit_diag_L24                                 5000.0  6.200000e-03
# CountVisit_diag_J39                                 5000.0  2.200000e-03
# CountVisit_diag_J32                                 5000.0  2.400000e-03
# CountVisit_diag_B00                                 5000.0  7.000000e-03
# CountVisit_diag_L64                                 5000.0  2.800000e-03
# CountVisit_diag_Y42                                 5000.0  1.740000e-02
# CountVisit_diag_R10                                 5000.0  1.440000e-02
# CountVisit_diag_M10                                 5000.0  2.500000e-02
# CountVisit_diag_M75                                 5000.0  2.400000e-03
# CountVisit_diag_Z02                                 5000.0  1.100000e-02
# CountVisit_diag_J03                                 5000.0  5.600000e-03
# CountVisit_diag_R07                                 5000.0  3.400000e-03
# CountVisit_diag_K13                                 5000.0  3.800000e-03
# CountVisit_diag_Z30                                 5000.0  3.400000e-03
# CountVisit_diag_P39                                 5000.0  2.800000e-03
# CountVisit_diag_R22                                 5000.0  5.000000e-03
# CountVisit_diag_H60                                 5000.0  4.800000e-03
# CountVisit_diag_B02                                 5000.0  2.400000e-03
# CountVisit_diag_L29                                 5000.0  4.000000e-03
# CountVisit_diag_E05                                 5000.0  2.400000e-03
# CountVisit_diag_N64                                 5000.0  6.200000e-03
# CountVisit_diag_R05                                 5000.0  3.000000e-03
# CountVisit_diag_L60                                 5000.0  3.000000e-03
# CountVisit_diag_S80                                 5000.0  2.200000e-03
# CountVisit_diag_M65                                 5000.0  3.800000e-03
# CountVisit_diag_J22                                 5000.0  4.200000e-03
# CountVisit_diag_O21                                 5000.0  2.600000e-03
# CountVisit_diag_M72                                 5000.0  2.600000e-03
# CountVisit_diag_L23                                 5000.0  2.400000e-03
# CountVisit_diag_K52                                 5000.0  3.800000e-03
# CountVisit_chronic_NoneChronic                      5000.0  1.746800e+00
# CountVisit_chronic_Atopic_dermatitis                5000.0  3.900000e-02
# CountVisit_chronic_Migraine                         5000.0  3.800000e-02
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis  5000.0  7.540000e-02
# CountVisit_chronic_Gastro-oesophageal_reflux_di...  5000.0  4.000000e-02
# CountVisit_chronic_Hypertension                     5000.0  4.820000e-02
# CountVisit_chronic_Asthma                           5000.0  2.960000e-02
# CountVisit_chronic_Hyperlipidaemia                  5000.0  3.520000e-02
# CountVisit_chronic_Thyroid                          5000.0  8.800000e-03
# CountVisit_chronic_Diabetes                         5000.0  1.140000e-02
# CountVisit_chronic_Gout                             5000.0  2.500000e-02
# CountVisit_symp_others                              5000.0  7.952000e-01
# CountVisit_symp_medical_referral                    5000.0  8.300000e-02
# CountVisit_symp_headache                            5000.0  4.674000e-01
# CountVisit_symp_giddiness                           5000.0  4.480000e-01
# CountVisit_symp_fever                               5000.0  1.114000e-01
# CountVisit_symp_N                                   5000.0  2.310000e-01
# CountVisit_symp_cold_sores                          5000.0  1.142000e-01
# CountVisit_symp_rash                                5000.0  1.178000e-01
# CountVisit_symp_sore_throat                         5000.0  1.992000e-01
# CountVisit_symp_flu                                 5000.0  1.980000e-01
# CountVisit_symp_cough                               5000.0  1.956000e-01
# CountVisit_symp_cold                                5000.0  3.070000e-01
# CountVisit_symp_vomiting                            5000.0  2.658000e-01
# CountVisit_symp_diarrhoea                           5000.0  2.804000e-01
# CountVisit_symp_chronic_medicine_top-up             5000.0  8.380000e-02
# CountVisit_symp_chronic_illness_management          5000.0  1.140000e-02
# CountVisit_symp_discuss_lab_results                 5000.0  5.100000e-02
# DiffDays_Vist                                       5000.0  6.123240e+01
# Ave_VisitGapDays                                    5000.0  1.856500e+01
# Target_Chronic                                      5000.0  1.688000e-01
# Target_Dermatitis                                   5000.0  3.160000e-02
# Target_Migraine                                     5000.0  2.660000e-02
# Target_Allergic                                     5000.0  5.060000e-02
# Target_Gastro                                       5000.0  3.120000e-02
# Target_Hypertension                                 5000.0  1.960000e-02
# Target_Asthma                                       5000.0  1.740000e-02
# Target_Hyperlipidaemia                              5000.0  1.800000e-02
# Target_Thyroid                                      5000.0  5.400000e-03
# Target_Diabetes                                     5000.0  5.800000e-03
# Target_Gout                                         5000.0  1.600000e-02
# Target_3High                                        5000.0  3.100000e-02
# Target_Allergic_Dermatitis_Asthma                   5000.0  8.680000e-02
# Target_Migraine_Gastro_Thyroid_Gout                 5000.0  7.520000e-02
# ConsultHr_8to10                                     5000.0  6.876000e-01
# ConsultHr_11to13                                    5000.0  5.102000e-01
# ConsultHr_14to17                                    5000.0  5.270000e-01
# ConsultHr_18to21                                    5000.0  2.686000e-01
# ConsultHr_22to23                                    5000.0  5.060000e-02
# Prin1_sym_common                                    5000.0  2.452882e-15
# Prin2_sym_rash                                      5000.0  6.911249e-16
# Prin3_sym_headache                                  5000.0  6.336487e-16
# Prin4_sym_diarrhea                                  5000.0 -1.091488e-16
#
#                                                           std        min  \
# Mem_CountBooking                                     1.761723   1.000000
# AVE_mc_days                                          1.309304   0.000000
# AVE_count_diagnosis                                  0.379076   1.000000
# AVE_count_chronic                                    0.315025   0.000000
# AVE_count_medication                                 1.379489   0.000000
# AVE_count_repeatmed                                  0.467920   0.000000
# AVE_count_SymID                                      1.302823   0.000000
# age_yr                                              10.102777  17.000000
# WaviedCount_FOLLOW_UP                                0.232142   0.000000
# WaviedCount_HEALTH_SCREENING_REVIEW                  0.184303   0.000000
# WaviedCount_OTHERS                                   0.134084   0.000000
# WaviedCount_REFERRAL                                 0.024490   0.000000
# WaviedCount_UNSUITABLE_FOR_TELECONSULT               0.094450   0.000000
# WaviedCount_WHITECOAT_FAMILY                         0.081193   0.000000
# CountVisit_is_mc_issued                              1.495579   0.000000
# CountVisit_is_referral_letter_issued                 0.435399   0.000000
# CountVisit_Target_chronic                            0.866431   0.000000
# CountVisit_diag_H57                                  0.190635   0.000000
# CountVisit_diag_M23                                  0.076049   0.000000
# CountVisit_diag_T88                                  0.323884   0.000000
# CountVisit_diag_L20                                  0.245542   0.000000
# CountVisit_diag_R51                                  0.580882   0.000000
# CountVisit_diag_N94                                  0.447689   0.000000
# CountVisit_diag_G44                                  0.265079   0.000000
# CountVisit_diag_M79                                  0.287978   0.000000
# CountVisit_diag_J02                                  0.151064   0.000000
# CountVisit_diag_J06                                  0.443415   0.000000
# CountVisit_diag_G43                                  0.289435   0.000000
# CountVisit_diag_R21                                  0.261405   0.000000
# CountVisit_diag_M62                                  0.276667   0.000000
# CountVisit_diag_A09                                  0.544962   0.000000
# CountVisit_diag_J30                                  0.387031   0.000000
# CountVisit_diag_L30                                  0.142331   0.000000
# CountVisit_diag_T78                                  0.149886   0.000000
# CountVisit_diag_U07                                  0.209767   0.000000
# CountVisit_diag_K29                                  0.289477   0.000000
# CountVisit_diag_B35                                  0.175015   0.000000
# CountVisit_diag_K30                                  0.225737   0.000000
# CountVisit_diag_H81                                  0.141120   0.000000
# CountVisit_diag_N39                                  0.236563   0.000000
# CountVisit_diag_G47                                  0.128113   0.000000
# CountVisit_diag_Z76                                  0.154733   0.000000
# CountVisit_diag_K59                                  0.185731   0.000000
# CountVisit_diag_H10                                  0.178130   0.000000
# CountVisit_diag_R42                                  0.167333   0.000000
# CountVisit_diag_K21                                  0.249023   0.000000
# CountVisit_diag_S90                                  0.076026   0.000000
# CountVisit_diag_R50                                  0.203981   0.000000
# CountVisit_diag_U12                                  0.132443   0.000000
# CountVisit_diag_N92                                  0.097694   0.000000
# CountVisit_diag_M54                                  0.273315   0.000000
# CountVisit_diag_S60                                  0.052846   0.000000
# CountVisit_diag_I10                                  0.407858   0.000000
# CountVisit_diag_L03                                  0.107211   0.000000
# CountVisit_diag_K64                                  0.117943   0.000000
# CountVisit_diag_L98                                  0.109875   0.000000
# CountVisit_diag_B37                                  0.148294   0.000000
# CountVisit_diag_L73                                  0.059941   0.000000
# CountVisit_diag_H00                                  0.174729   0.000000
# CountVisit_diag_N76                                  0.098697   0.000000
# CountVisit_diag_J01                                  0.118893   0.000000
# CountVisit_diag_J45                                  0.262940   0.000000
# CountVisit_diag_E78                                  0.334917   0.000000
# CountVisit_diag_L02                                  0.102671   0.000000
# CountVisit_diag_R52                                  0.073322   0.000000
# CountVisit_diag_K12                                  0.119525   0.000000
# CountVisit_diag_K58                                  0.113860   0.000000
# CountVisit_diag_K07                                  0.052846   0.000000
# CountVisit_diag_L70                                  0.085929   0.000000
# CountVisit_diag_Z71                                  0.187035   0.000000
# CountVisit_diag_S63                                  0.063149   0.000000
# CountVisit_diag_M25                                  0.109098   0.000000
# CountVisit_diag_K05                                  0.059921   0.000000
# CountVisit_diag_E03                                  0.115604   0.000000
# CountVisit_diag_L50                                  0.178035   0.000000
# CountVisit_diag_W57                                  0.085778   0.000000
# CountVisit_diag_H93                                  0.054696   0.000000
# CountVisit_diag_H01                                  0.110916   0.000000
# CountVisit_diag_E11                                  0.176825   0.000000
# CountVisit_diag_S13                                  0.059921   0.000000
# CountVisit_diag_F41                                  0.076070   0.000000
# CountVisit_diag_R53                                  0.117502   0.000000
# CountVisit_diag_O91                                  0.048936   0.000000
# CountVisit_diag_H02                                  0.067674   0.000000
# CountVisit_diag_R11                                  0.145010   0.000000
# CountVisit_diag_S93                                  0.082252   0.000000
# CountVisit_diag_L24                                  0.085808   0.000000
# CountVisit_diag_J39                                  0.050948   0.000000
# CountVisit_diag_J32                                  0.069247   0.000000
# CountVisit_diag_B00                                  0.094619   0.000000
# CountVisit_diag_L64                                  0.069232   0.000000
# CountVisit_diag_Y42                                  0.168235   0.000000
# CountVisit_diag_R10                                  0.130369   0.000000
# CountVisit_diag_M10                                  0.227124   0.000000
# CountVisit_diag_M75                                  0.048936   0.000000
# CountVisit_diag_Z02                                  0.115246   0.000000
# CountVisit_diag_J03                                  0.097829   0.000000
# CountVisit_diag_R07                                  0.061556   0.000000
# CountVisit_diag_K13                                  0.061533   0.000000
# CountVisit_diag_Z30                                  0.064725   0.000000
# CountVisit_diag_P39                                  0.056505   0.000000
# CountVisit_diag_R22                                  0.070541   0.000000
# CountVisit_diag_H60                                  0.074687   0.000000
# CountVisit_diag_B02                                  0.052866   0.000000
# CountVisit_diag_L29                                  0.069173   0.000000
# CountVisit_diag_E05                                  0.077430   0.000000
# CountVisit_diag_N64                                  0.096765   0.000000
# CountVisit_diag_R05                                  0.064744   0.000000
# CountVisit_diag_L60                                  0.058238   0.000000
# CountVisit_diag_S80                                  0.046857   0.000000
# CountVisit_diag_M65                                  0.061533   0.000000
# CountVisit_diag_J22                                  0.064678   0.000000
# CountVisit_diag_O21                                  0.070670   0.000000
# CountVisit_diag_M72                                  0.050929   0.000000
# CountVisit_diag_L23                                  0.052866   0.000000
# CountVisit_diag_K52                                  0.061533   0.000000
# CountVisit_chronic_NoneChronic                       1.522745   0.000000
# CountVisit_chronic_Atopic_dermatitis                 0.245542   0.000000
# CountVisit_chronic_Migraine                          0.289435   0.000000
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis   0.383333   0.000000
# CountVisit_chronic_Gastro-oesophageal_reflux_di...   0.249023   0.000000
# CountVisit_chronic_Hypertension                      0.410257   0.000000
# CountVisit_chronic_Asthma                            0.262940   0.000000
# CountVisit_chronic_Hyperlipidaemia                   0.334639   0.000000
# CountVisit_chronic_Thyroid                           0.139737   0.000000
# CountVisit_chronic_Diabetes                          0.174574   0.000000
# CountVisit_chronic_Gout                              0.227124   0.000000
# CountVisit_symp_others                               1.039362   0.000000
# CountVisit_symp_medical_referral                     0.352329   0.000000
# CountVisit_symp_headache                             0.877206   0.000000
# CountVisit_symp_giddiness                            0.851258   0.000000
# CountVisit_symp_fever                                0.356953   0.000000
# CountVisit_symp_N                                    0.844382   0.000000
# CountVisit_symp_cold_sores                           0.411816   0.000000
# CountVisit_symp_rash                                 0.418041   0.000000
# CountVisit_symp_sore_throat                          0.493931   0.000000
# CountVisit_symp_flu                                  0.491166   0.000000
# CountVisit_symp_cough                                0.489273   0.000000
# CountVisit_symp_cold                                 0.639713   0.000000
# CountVisit_symp_vomiting                             0.595669   0.000000
# CountVisit_symp_diarrhoea                            0.616321   0.000000
# CountVisit_symp_chronic_medicine_top-up              0.446786   0.000000
# CountVisit_symp_chronic_illness_management           0.115207   0.000000
# CountVisit_symp_discuss_lab_results                  0.230672   0.000000
# DiffDays_Vist                                       95.553364   0.000000
# Ave_VisitGapDays                                    29.184717   0.000000
# Target_Chronic                                       0.374613   0.000000
# Target_Dermatitis                                    0.174950   0.000000
# Target_Migraine                                      0.160927   0.000000
# Target_Allergic                                      0.219201   0.000000
# Target_Gastro                                        0.173875   0.000000
# Target_Hypertension                                  0.138635   0.000000
# Target_Asthma                                        0.130769   0.000000
# Target_Hyperlipidaemia                               0.132964   0.000000
# Target_Thyroid                                       0.073293   0.000000
# Target_Diabetes                                      0.075944   0.000000
# Target_Gout                                          0.125488   0.000000
# Target_3High                                         0.173335   0.000000
# Target_Allergic_Dermatitis_Asthma                    0.281570   0.000000
# Target_Migraine_Gastro_Thyroid_Gout                  0.263740   0.000000
# ConsultHr_8to10                                      1.043563   0.000000
# ConsultHr_11to13                                     0.809461   0.000000
# ConsultHr_14to17                                     0.863840   0.000000
# ConsultHr_18to21                                     0.632878   0.000000
# ConsultHr_22to23                                     0.249904   0.000000
# Prin1_sym_common                                     1.952173  -1.082006
# Prin2_sym_rash                                       1.474141  -6.709039
# Prin3_sym_headache                                   1.536508  -8.550789
# Prin4_sym_diarrhea                                   1.244230 -12.083743
#
#                                                           25%        50%  \
# Mem_CountBooking                                     1.000000   1.000000
# AVE_mc_days                                          0.000000   1.000000
# AVE_count_diagnosis                                  1.000000   1.000000
# AVE_count_chronic                                    0.000000   0.000000
# AVE_count_medication                                 1.000000   2.000000
# AVE_count_repeatmed                                  0.000000   1.000000
# AVE_count_SymID                                      1.000000   1.000000
# age_yr                                              29.000000  34.000000
# WaviedCount_FOLLOW_UP                                0.000000   0.000000
# WaviedCount_HEALTH_SCREENING_REVIEW                  0.000000   0.000000
# WaviedCount_OTHERS                                   0.000000   0.000000
# WaviedCount_REFERRAL                                 0.000000   0.000000
# WaviedCount_UNSUITABLE_FOR_TELECONSULT               0.000000   0.000000
# WaviedCount_WHITECOAT_FAMILY                         0.000000   0.000000
# CountVisit_is_mc_issued                              0.000000   1.000000
# CountVisit_is_referral_letter_issued                 0.000000   0.000000
# CountVisit_Target_chronic                            0.000000   0.000000
# CountVisit_diag_H57                                  0.000000   0.000000
# CountVisit_diag_M23                                  0.000000   0.000000
# CountVisit_diag_T88                                  0.000000   0.000000
# CountVisit_diag_L20                                  0.000000   0.000000
# CountVisit_diag_R51                                  0.000000   0.000000
# CountVisit_diag_N94                                  0.000000   0.000000
# CountVisit_diag_G44                                  0.000000   0.000000
# CountVisit_diag_M79                                  0.000000   0.000000
# CountVisit_diag_J02                                  0.000000   0.000000
# CountVisit_diag_J06                                  0.000000   0.000000
# CountVisit_diag_G43                                  0.000000   0.000000
# CountVisit_diag_R21                                  0.000000   0.000000
# CountVisit_diag_M62                                  0.000000   0.000000
# CountVisit_diag_A09                                  0.000000   0.000000
# CountVisit_diag_J30                                  0.000000   0.000000
# CountVisit_diag_L30                                  0.000000   0.000000
# CountVisit_diag_T78                                  0.000000   0.000000
# CountVisit_diag_U07                                  0.000000   0.000000
# CountVisit_diag_K29                                  0.000000   0.000000
# CountVisit_diag_B35                                  0.000000   0.000000
# CountVisit_diag_K30                                  0.000000   0.000000
# CountVisit_diag_H81                                  0.000000   0.000000
# CountVisit_diag_N39                                  0.000000   0.000000
# CountVisit_diag_G47                                  0.000000   0.000000
# CountVisit_diag_Z76                                  0.000000   0.000000
# CountVisit_diag_K59                                  0.000000   0.000000
# CountVisit_diag_H10                                  0.000000   0.000000
# CountVisit_diag_R42                                  0.000000   0.000000
# CountVisit_diag_K21                                  0.000000   0.000000
# CountVisit_diag_S90                                  0.000000   0.000000
# CountVisit_diag_R50                                  0.000000   0.000000
# CountVisit_diag_U12                                  0.000000   0.000000
# CountVisit_diag_N92                                  0.000000   0.000000
# CountVisit_diag_M54                                  0.000000   0.000000
# CountVisit_diag_S60                                  0.000000   0.000000
# CountVisit_diag_I10                                  0.000000   0.000000
# CountVisit_diag_L03                                  0.000000   0.000000
# CountVisit_diag_K64                                  0.000000   0.000000
# CountVisit_diag_L98                                  0.000000   0.000000
# CountVisit_diag_B37                                  0.000000   0.000000
# CountVisit_diag_L73                                  0.000000   0.000000
# CountVisit_diag_H00                                  0.000000   0.000000
# CountVisit_diag_N76                                  0.000000   0.000000
# CountVisit_diag_J01                                  0.000000   0.000000
# CountVisit_diag_J45                                  0.000000   0.000000
# CountVisit_diag_E78                                  0.000000   0.000000
# CountVisit_diag_L02                                  0.000000   0.000000
# CountVisit_diag_R52                                  0.000000   0.000000
# CountVisit_diag_K12                                  0.000000   0.000000
# CountVisit_diag_K58                                  0.000000   0.000000
# CountVisit_diag_K07                                  0.000000   0.000000
# CountVisit_diag_L70                                  0.000000   0.000000
# CountVisit_diag_Z71                                  0.000000   0.000000
# CountVisit_diag_S63                                  0.000000   0.000000
# CountVisit_diag_M25                                  0.000000   0.000000
# CountVisit_diag_K05                                  0.000000   0.000000
# CountVisit_diag_E03                                  0.000000   0.000000
# CountVisit_diag_L50                                  0.000000   0.000000
# CountVisit_diag_W57                                  0.000000   0.000000
# CountVisit_diag_H93                                  0.000000   0.000000
# CountVisit_diag_H01                                  0.000000   0.000000
# CountVisit_diag_E11                                  0.000000   0.000000
# CountVisit_diag_S13                                  0.000000   0.000000
# CountVisit_diag_F41                                  0.000000   0.000000
# CountVisit_diag_R53                                  0.000000   0.000000
# CountVisit_diag_O91                                  0.000000   0.000000
# CountVisit_diag_H02                                  0.000000   0.000000
# CountVisit_diag_R11                                  0.000000   0.000000
# CountVisit_diag_S93                                  0.000000   0.000000
# CountVisit_diag_L24                                  0.000000   0.000000
# CountVisit_diag_J39                                  0.000000   0.000000
# CountVisit_diag_J32                                  0.000000   0.000000
# CountVisit_diag_B00                                  0.000000   0.000000
# CountVisit_diag_L64                                  0.000000   0.000000
# CountVisit_diag_Y42                                  0.000000   0.000000
# CountVisit_diag_R10                                  0.000000   0.000000
# CountVisit_diag_M10                                  0.000000   0.000000
# CountVisit_diag_M75                                  0.000000   0.000000
# CountVisit_diag_Z02                                  0.000000   0.000000
# CountVisit_diag_J03                                  0.000000   0.000000
# CountVisit_diag_R07                                  0.000000   0.000000
# CountVisit_diag_K13                                  0.000000   0.000000
# CountVisit_diag_Z30                                  0.000000   0.000000
# CountVisit_diag_P39                                  0.000000   0.000000
# CountVisit_diag_R22                                  0.000000   0.000000
# CountVisit_diag_H60                                  0.000000   0.000000
# CountVisit_diag_B02                                  0.000000   0.000000
# CountVisit_diag_L29                                  0.000000   0.000000
# CountVisit_diag_E05                                  0.000000   0.000000
# CountVisit_diag_N64                                  0.000000   0.000000
# CountVisit_diag_R05                                  0.000000   0.000000
# CountVisit_diag_L60                                  0.000000   0.000000
# CountVisit_diag_S80                                  0.000000   0.000000
# CountVisit_diag_M65                                  0.000000   0.000000
# CountVisit_diag_J22                                  0.000000   0.000000
# CountVisit_diag_O21                                  0.000000   0.000000
# CountVisit_diag_M72                                  0.000000   0.000000
# CountVisit_diag_L23                                  0.000000   0.000000
# CountVisit_diag_K52                                  0.000000   0.000000
# CountVisit_chronic_NoneChronic                       1.000000   1.000000
# CountVisit_chronic_Atopic_dermatitis                 0.000000   0.000000
# CountVisit_chronic_Migraine                          0.000000   0.000000
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis   0.000000   0.000000
# CountVisit_chronic_Gastro-oesophageal_reflux_di...   0.000000   0.000000
# CountVisit_chronic_Hypertension                      0.000000   0.000000
# CountVisit_chronic_Asthma                            0.000000   0.000000
# CountVisit_chronic_Hyperlipidaemia                   0.000000   0.000000
# CountVisit_chronic_Thyroid                           0.000000   0.000000
# CountVisit_chronic_Diabetes                          0.000000   0.000000
# CountVisit_chronic_Gout                              0.000000   0.000000
# CountVisit_symp_others                               0.000000   1.000000
# CountVisit_symp_medical_referral                     0.000000   0.000000
# CountVisit_symp_headache                             0.000000   0.000000
# CountVisit_symp_giddiness                            0.000000   0.000000
# CountVisit_symp_fever                                0.000000   0.000000
# CountVisit_symp_N                                    0.000000   0.000000
# CountVisit_symp_cold_sores                           0.000000   0.000000
# CountVisit_symp_rash                                 0.000000   0.000000
# CountVisit_symp_sore_throat                          0.000000   0.000000
# CountVisit_symp_flu                                  0.000000   0.000000
# CountVisit_symp_cough                                0.000000   0.000000
# CountVisit_symp_cold                                 0.000000   0.000000
# CountVisit_symp_vomiting                             0.000000   0.000000
# CountVisit_symp_diarrhoea                            0.000000   0.000000
# CountVisit_symp_chronic_medicine_top-up              0.000000   0.000000
# CountVisit_symp_chronic_illness_management           0.000000   0.000000
# CountVisit_symp_discuss_lab_results                  0.000000   0.000000
# DiffDays_Vist                                        0.000000   0.000000
# Ave_VisitGapDays                                     0.000000   0.000000
# Target_Chronic                                       0.000000   0.000000
# Target_Dermatitis                                    0.000000   0.000000
# Target_Migraine                                      0.000000   0.000000
# Target_Allergic                                      0.000000   0.000000
# Target_Gastro                                        0.000000   0.000000
# Target_Hypertension                                  0.000000   0.000000
# Target_Asthma                                        0.000000   0.000000
# Target_Hyperlipidaemia                               0.000000   0.000000
# Target_Thyroid                                       0.000000   0.000000
# Target_Diabetes                                      0.000000   0.000000
# Target_Gout                                          0.000000   0.000000
# Target_3High                                         0.000000   0.000000
# Target_Allergic_Dermatitis_Asthma                    0.000000   0.000000
# Target_Migraine_Gastro_Thyroid_Gout                  0.000000   0.000000
# ConsultHr_8to10                                      0.000000   0.000000
# ConsultHr_11to13                                     0.000000   0.000000
# ConsultHr_14to17                                     0.000000   0.000000
# ConsultHr_18to21                                     0.000000   0.000000
# ConsultHr_22to23                                     0.000000   0.000000
# Prin1_sym_common                                    -1.082006  -0.864910
# Prin2_sym_rash                                      -0.399412  -0.399412
# Prin3_sym_headache                                  -0.711590  -0.711590
# Prin4_sym_diarrhea                                  -0.309161   0.042277
#
#                                                            75%         max
# Mem_CountBooking                                      2.000000   19.000000
# AVE_mc_days                                           1.000000    7.000000
# AVE_count_diagnosis                                   1.000000    5.000000
# AVE_count_chronic                                     0.000000    3.000000
# AVE_count_medication                                  3.000000    8.000000
# AVE_count_repeatmed                                   1.000000    5.000000
# AVE_count_SymID                                       2.000000   10.000000
# age_yr                                               41.000000  102.000000
# WaviedCount_FOLLOW_UP                                 0.000000    6.000000
# WaviedCount_HEALTH_SCREENING_REVIEW                   0.000000    1.000000
# WaviedCount_OTHERS                                    0.000000    3.000000
# WaviedCount_REFERRAL                                  0.000000    1.000000
# WaviedCount_UNSUITABLE_FOR_TELECONSULT                0.000000    1.000000
# WaviedCount_WHITECOAT_FAMILY                          0.000000    3.000000
# CountVisit_is_mc_issued                               2.000000   14.000000
# CountVisit_is_referral_letter_issued                  0.000000    9.000000
# CountVisit_Target_chronic                             0.000000   13.000000
# CountVisit_diag_H57                                   0.000000    5.000000
# CountVisit_diag_M23                                   0.000000    3.000000
# CountVisit_diag_T88                                   0.000000    2.000000
# CountVisit_diag_L20                                   0.000000    6.000000
# CountVisit_diag_R51                                   0.000000    7.000000
# CountVisit_diag_N94                                   0.000000    6.000000
# CountVisit_diag_G44                                   0.000000    3.000000
# CountVisit_diag_M79                                   0.000000    3.000000
# CountVisit_diag_J02                                   0.000000    3.000000
# CountVisit_diag_J06                                   0.000000    5.000000
# CountVisit_diag_G43                                   0.000000    9.000000
# CountVisit_diag_R21                                   0.000000    3.000000
# CountVisit_diag_M62                                   0.000000    3.000000
# CountVisit_diag_A09                                   0.000000    6.000000
# CountVisit_diag_J30                                   0.000000    7.000000
# CountVisit_diag_L30                                   0.000000    2.000000
# CountVisit_diag_T78                                   0.000000    3.000000
# CountVisit_diag_U07                                   0.000000    4.000000
# CountVisit_diag_K29                                   0.000000    5.000000
# CountVisit_diag_B35                                   0.000000    3.000000
# CountVisit_diag_K30                                   0.000000    5.000000
# CountVisit_diag_H81                                   0.000000    3.000000
# CountVisit_diag_N39                                   0.000000    4.000000
# CountVisit_diag_G47                                   0.000000    3.000000
# CountVisit_diag_Z76                                   0.000000    4.000000
# CountVisit_diag_K59                                   0.000000    6.000000
# CountVisit_diag_H10                                   0.000000    3.000000
# CountVisit_diag_R42                                   0.000000    3.000000
# CountVisit_diag_K21                                   0.000000    4.000000
# CountVisit_diag_S90                                   0.000000    3.000000
# CountVisit_diag_R50                                   0.000000    3.000000
# CountVisit_diag_U12                                   0.000000    2.000000
# CountVisit_diag_N92                                   0.000000    3.000000
# CountVisit_diag_M54                                   0.000000    4.000000
# CountVisit_diag_S60                                   0.000000    1.000000
# CountVisit_diag_I10                                   0.000000    7.000000
# CountVisit_diag_L03                                   0.000000    2.000000
# CountVisit_diag_K64                                   0.000000    3.000000
# CountVisit_diag_L98                                   0.000000    2.000000
# CountVisit_diag_B37                                   0.000000    3.000000
# CountVisit_diag_L73                                   0.000000    2.000000
# CountVisit_diag_H00                                   0.000000    2.000000
# CountVisit_diag_N76                                   0.000000    2.000000
# CountVisit_diag_J01                                   0.000000    5.000000
# CountVisit_diag_J45                                   0.000000    5.000000
# CountVisit_diag_E78                                   0.000000   12.000000
# CountVisit_diag_L02                                   0.000000    3.000000
# CountVisit_diag_R52                                   0.000000    2.000000
# CountVisit_diag_K12                                   0.000000    4.000000
# CountVisit_diag_K58                                   0.000000    5.000000
# CountVisit_diag_K07                                   0.000000    1.000000
# CountVisit_diag_L70                                   0.000000    3.000000
# CountVisit_diag_Z71                                   0.000000    2.000000
# CountVisit_diag_S63                                   0.000000    2.000000
# CountVisit_diag_M25                                   0.000000    2.000000
# CountVisit_diag_K05                                   0.000000    2.000000
# CountVisit_diag_E03                                   0.000000    4.000000
# CountVisit_diag_L50                                   0.000000    5.000000
# CountVisit_diag_W57                                   0.000000    2.000000
# CountVisit_diag_H93                                   0.000000    1.000000
# CountVisit_diag_H01                                   0.000000    2.000000
# CountVisit_diag_E11                                   0.000000    5.000000
# CountVisit_diag_S13                                   0.000000    2.000000
# CountVisit_diag_F41                                   0.000000    3.000000
# CountVisit_diag_R53                                   0.000000    1.000000
# CountVisit_diag_O91                                   0.000000    1.000000
# CountVisit_diag_H02                                   0.000000    1.000000
# CountVisit_diag_R11                                   0.000000    3.000000
# CountVisit_diag_S93                                   0.000000    2.000000
# CountVisit_diag_L24                                   0.000000    3.000000
# CountVisit_diag_J39                                   0.000000    2.000000
# CountVisit_diag_J32                                   0.000000    3.000000
# CountVisit_diag_B00                                   0.000000    3.000000
# CountVisit_diag_L64                                   0.000000    3.000000
# CountVisit_diag_Y42                                   0.000000    4.000000
# CountVisit_diag_R10                                   0.000000    3.000000
# CountVisit_diag_M10                                   0.000000    5.000000
# CountVisit_diag_M75                                   0.000000    1.000000
# CountVisit_diag_Z02                                   0.000000    3.000000
# CountVisit_diag_J03                                   0.000000    4.000000
# CountVisit_diag_R07                                   0.000000    2.000000
# CountVisit_diag_K13                                   0.000000    1.000000
# CountVisit_diag_Z30                                   0.000000    2.000000
# CountVisit_diag_P39                                   0.000000    2.000000
# CountVisit_diag_R22                                   0.000000    1.000000
# CountVisit_diag_H60                                   0.000000    2.000000
# CountVisit_diag_B02                                   0.000000    2.000000
# CountVisit_diag_L29                                   0.000000    2.000000
# CountVisit_diag_E05                                   0.000000    4.000000
# CountVisit_diag_N64                                   0.000000    3.000000
# CountVisit_diag_R05                                   0.000000    3.000000
# CountVisit_diag_L60                                   0.000000    2.000000
# CountVisit_diag_S80                                   0.000000    1.000000
# CountVisit_diag_M65                                   0.000000    1.000000
# CountVisit_diag_J22                                   0.000000    1.000000
# CountVisit_diag_O21                                   0.000000    3.000000
# CountVisit_diag_M72                                   0.000000    1.000000
# CountVisit_diag_L23                                   0.000000    2.000000
# CountVisit_diag_K52                                   0.000000    1.000000
# CountVisit_chronic_NoneChronic                        2.000000   13.000000
# CountVisit_chronic_Atopic_dermatitis                  0.000000    6.000000
# CountVisit_chronic_Migraine                           0.000000    9.000000
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis    0.000000    7.000000
# CountVisit_chronic_Gastro-oesophageal_reflux_di...    0.000000    4.000000
# CountVisit_chronic_Hypertension                       0.000000    7.000000
# CountVisit_chronic_Asthma                             0.000000    5.000000
# CountVisit_chronic_Hyperlipidaemia                    0.000000   12.000000
# CountVisit_chronic_Thyroid                            0.000000    4.000000
# CountVisit_chronic_Diabetes                           0.000000    5.000000
# CountVisit_chronic_Gout                               0.000000    5.000000
# CountVisit_symp_others                                1.000000    9.000000
# CountVisit_symp_medical_referral                      0.000000    8.000000
# CountVisit_symp_headache                              1.000000   11.000000
# CountVisit_symp_giddiness                             1.000000   11.000000
# CountVisit_symp_fever                                 0.000000    5.000000
# CountVisit_symp_N                                     0.000000   17.000000
# CountVisit_symp_cold_sores                            0.000000    8.000000
# CountVisit_symp_rash                                  0.000000    8.000000
# CountVisit_symp_sore_throat                           0.000000    5.000000
# CountVisit_symp_flu                                   0.000000    5.000000
# CountVisit_symp_cough                                 0.000000    5.000000
# CountVisit_symp_cold                                  0.000000    9.000000
# CountVisit_symp_vomiting                              0.000000    6.000000
# CountVisit_symp_diarrhoea                             0.000000    6.000000
# CountVisit_symp_chronic_medicine_top-up               0.000000    7.000000
# CountVisit_symp_chronic_illness_management            0.000000    2.000000
# CountVisit_symp_discuss_lab_results                   0.000000    3.000000
# DiffDays_Vist                                       104.000000  359.000000
# Ave_VisitGapDays                                     33.000000  173.000000
# Target_Chronic                                        0.000000    1.000000
# Target_Dermatitis                                     0.000000    1.000000
# Target_Migraine                                       0.000000    1.000000
# Target_Allergic                                       0.000000    1.000000
# Target_Gastro                                         0.000000    1.000000
# Target_Hypertension                                   0.000000    1.000000
# Target_Asthma                                         0.000000    1.000000
# Target_Hyperlipidaemia                                0.000000    1.000000
# Target_Thyroid                                        0.000000    1.000000
# Target_Diabetes                                       0.000000    1.000000
# Target_Gout                                           0.000000    1.000000
# Target_3High                                          0.000000    1.000000
# Target_Allergic_Dermatitis_Asthma                     0.000000    1.000000
# Target_Migraine_Gastro_Thyroid_Gout                   0.000000    1.000000
# ConsultHr_8to10                                       1.000000   13.000000
# ConsultHr_11to13                                      1.000000    9.000000
# ConsultHr_14to17                                      1.000000   10.000000
# ConsultHr_18to21                                      0.000000   11.000000
# ConsultHr_22to23                                      0.000000    3.000000
# Prin1_sym_common                                      0.182531   20.301158
# Prin2_sym_rash                                        0.151058   26.179093
# Prin3_sym_headache                                    0.549486   11.876045
# Prin4_sym_diarrhea                                    0.257462    8.426631

# %%
df.isnull().sum()
# Out:
# mem_id                                                  0
# gender                                                  0
# Mem_CountBooking                                        0
# AVE_mc_days                                             0
# AVE_count_diagnosis                                     0
# AVE_count_chronic                                       0
# AVE_count_medication                                    0
# AVE_count_repeatmed                                     0
# AVE_count_SymID                                         0
# age_yr                                                  0
# WaviedCount_FOLLOW_UP                                   0
# WaviedCount_HEALTH_SCREENING_REVIEW                     0
# WaviedCount_OTHERS                                      0
# WaviedCount_REFERRAL                                    0
# WaviedCount_UNSUITABLE_FOR_TELECONSULT                  0
# WaviedCount_WHITECOAT_FAMILY                            0
# CountVisit_is_mc_issued                                 0
# CountVisit_is_referral_letter_issued                    0
# CountVisit_Target_chronic                               0
# CountVisit_diag_H57                                     0
# CountVisit_diag_M23                                     0
# CountVisit_diag_T88                                     0
# CountVisit_diag_L20                                     0
# CountVisit_diag_R51                                     0
# CountVisit_diag_N94                                     0
# CountVisit_diag_G44                                     0
# CountVisit_diag_M79                                     0
# CountVisit_diag_J02                                     0
# CountVisit_diag_J06                                     0
# CountVisit_diag_G43                                     0
# CountVisit_diag_R21                                     0
# CountVisit_diag_M62                                     0
# CountVisit_diag_A09                                     0
# CountVisit_diag_J30                                     0
# CountVisit_diag_L30                                     0
# CountVisit_diag_T78                                     0
# CountVisit_diag_U07                                     0
# CountVisit_diag_K29                                     0
# CountVisit_diag_B35                                     0
# CountVisit_diag_K30                                     0
# CountVisit_diag_H81                                     0
# CountVisit_diag_N39                                     0
# CountVisit_diag_G47                                     0
# CountVisit_diag_Z76                                     0
# CountVisit_diag_K59                                     0
# CountVisit_diag_H10                                     0
# CountVisit_diag_R42                                     0
# CountVisit_diag_K21                                     0
# CountVisit_diag_S90                                     0
# CountVisit_diag_R50                                     0
# CountVisit_diag_U12                                     0
# CountVisit_diag_N92                                     0
# CountVisit_diag_M54                                     0
# CountVisit_diag_S60                                     0
# CountVisit_diag_I10                                     0
# CountVisit_diag_L03                                     0
# CountVisit_diag_K64                                     0
# CountVisit_diag_L98                                     0
# CountVisit_diag_B37                                     0
# CountVisit_diag_L73                                     0
# CountVisit_diag_H00                                     0
# CountVisit_diag_N76                                     0
# CountVisit_diag_J01                                     0
# CountVisit_diag_J45                                     0
# CountVisit_diag_E78                                     0
# CountVisit_diag_L02                                     0
# CountVisit_diag_R52                                     0
# CountVisit_diag_K12                                     0
# CountVisit_diag_K58                                     0
# CountVisit_diag_K07                                     0
# CountVisit_diag_L70                                     0
# CountVisit_diag_Z71                                     0
# CountVisit_diag_S63                                     0
# CountVisit_diag_M25                                     0
# CountVisit_diag_K05                                     0
# CountVisit_diag_E03                                     0
# CountVisit_diag_L50                                     0
# CountVisit_diag_W57                                     0
# CountVisit_diag_H93                                     0
# CountVisit_diag_H01                                     0
# CountVisit_diag_E11                                     0
# CountVisit_diag_S13                                     0
# CountVisit_diag_F41                                     0
# CountVisit_diag_R53                                     0
# CountVisit_diag_O91                                     0
# CountVisit_diag_H02                                     0
# CountVisit_diag_R11                                     0
# CountVisit_diag_S93                                     0
# CountVisit_diag_L24                                     0
# CountVisit_diag_J39                                     0
# CountVisit_diag_J32                                     0
# CountVisit_diag_B00                                     0
# CountVisit_diag_L64                                     0
# CountVisit_diag_Y42                                     0
# CountVisit_diag_R10                                     0
# CountVisit_diag_M10                                     0
# CountVisit_diag_M75                                     0
# CountVisit_diag_Z02                                     0
# CountVisit_diag_J03                                     0
# CountVisit_diag_R07                                     0
# CountVisit_diag_K13                                     0
# CountVisit_diag_Z30                                     0
# CountVisit_diag_P39                                     0
# CountVisit_diag_R22                                     0
# CountVisit_diag_H60                                     0
# CountVisit_diag_B02                                     0
# CountVisit_diag_L29                                     0
# CountVisit_diag_E05                                     0
# CountVisit_diag_N64                                     0
# CountVisit_diag_R05                                     0
# CountVisit_diag_L60                                     0
# CountVisit_diag_S80                                     0
# CountVisit_diag_M65                                     0
# CountVisit_diag_J22                                     0
# CountVisit_diag_O21                                     0
# CountVisit_diag_M72                                     0
# CountVisit_diag_L23                                     0
# CountVisit_diag_K52                                     0
# CountVisit_chronic_NoneChronic                          0
# CountVisit_chronic_Atopic_dermatitis                    0
# CountVisit_chronic_Migraine                             0
# CountVisit_chronic_Vasomotor_and_allergic_rhinitis      0
# CountVisit_chronic_Gastro-oesophageal_reflux_disease    0
# CountVisit_chronic_Hypertension                         0
# CountVisit_chronic_Asthma                               0
# CountVisit_chronic_Hyperlipidaemia                      0
# CountVisit_chronic_Thyroid                              0
# CountVisit_chronic_Diabetes                             0
# CountVisit_chronic_Gout                                 0
# CountVisit_symp_others                                  0
# CountVisit_symp_medical_referral                        0
# CountVisit_symp_headache                                0
# CountVisit_symp_giddiness                               0
# CountVisit_symp_fever                                   0
# CountVisit_symp_N                                       0
# CountVisit_symp_cold_sores                              0
# CountVisit_symp_rash                                    0
# CountVisit_symp_sore_throat                             0
# CountVisit_symp_flu                                     0
# CountVisit_symp_cough                                   0
# CountVisit_symp_cold                                    0
# CountVisit_symp_vomiting                                0
# CountVisit_symp_diarrhoea                               0
# CountVisit_symp_chronic_medicine_top-up                 0
# CountVisit_symp_chronic_illness_management              0
# CountVisit_symp_discuss_lab_results                     0
# DiffDays_Vist                                           0
# Ave_VisitGapDays                                        0
# Target_Chronic                                          0
# Target_Dermatitis                                       0
# Target_Migraine                                         0
# Target_Allergic                                         0
# Target_Gastro                                           0
# Target_Hypertension                                     0
# Target_Asthma                                           0
# Target_Hyperlipidaemia                                  0
# Target_Thyroid                                          0
# Target_Diabetes                                         0
# Target_Gout                                             0
# Target_3High                                            0
# Target_Allergic_Dermatitis_Asthma                       0
# Target_Migraine_Gastro_Thyroid_Gout                     0
# ConsultHr_8to10                                         0
# ConsultHr_11to13                                        0
# ConsultHr_14to17                                        0
# ConsultHr_18to21                                        0
# ConsultHr_22to23                                        0
# Prin1_sym_common                                        0
# Prin2_sym_rash                                          0
# Prin3_sym_headache                                      0
# Prin4_sym_diarrhea                                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
all_list = df.columns.tolist()

# %%
#[TODO] TO INCLUDE CATEGORICAL INPUT TO CONSIDER
cat_list = ["gender"]  
df[cat_list] = df[cat_list].astype("category")

# %%
#[TODO] EDIT WHERE NEC
# LWL: this exc_list is derived from Model6 v1 - By Member - Target AllergicNDermatitisNAsthma

exc_list = ['mem_id', 
            'Target_Chronic',
            'Target_Dermatitis',
            #'Target_Migraine',
            'Target_Allergic',
            #'Target_Gastro',
            #'Target_Hypertension',
            'Target_Asthma',
            #'Target_Hyperlipidaemia',
            #'Target_Thyroid',
            #'Target_Diabetes',
            #'Target_Gout', 
            "CountVisit_Target_chronic",
            "AVE_count_chronic", 
            'CountVisit_symp_chronic_medicine_top-up',
            'CountVisit_symp_chronic_illness_management',
            "CountVisit_chronic_NoneChronic", 
            "CountVisit_chronic_Atopic_dermatitis",
            #"CountVisit_chronic_Migraine",
            "CountVisit_chronic_Vasomotor_and_allergic_rhinitis",
            #"CountVisit_chronic_Gastro-oesophageal_reflux_disease",
            #"CountVisit_chronic_Hypertension",
            "CountVisit_chronic_Asthma",
            #"CountVisit_chronic_Hyperlipidaemia",
            #"CountVisit_chronic_Thyroid",
            #"CountVisit_chronic_Diabetes",
            #"CountVisit_chronic_Gout", 
            "CountVisit_diag_J30",  #Vasomotor and allergic rhinitis
            #"CountVisit_diag_K21",  #Gastro-esophageal reflux disease
            #"CountVisit_diag_G43",  #Migraine
            "CountVisit_diag_L20",  #Atopic dermatitis
            #"CountVisit_diag_M10",  #Gout
            #"CountVisit_diag_I10",  #hypertension
            "CountVisit_diag_J45",  #Asthma
            #"CountVisit_diag_E11",  #Diabetes
            #"CountVisit_diag_E78",  #hypercholesterolemia, hyperglyceridemia, Hyperlipidemia (high cholesterol), Hyperchylomicronemia 
            #"CountVisit_diag_E03",  #Other hypothyroidism, i.e. Thyroid 
            #"CountVisit_diag_E05",  #Thyrotoxicosis [hyperthyroidism], i.e. Thyroid
            "Target_3High",                                           
            "Target_Allergic_Dermatitis_Asthma",                                                   
            "Target_Migraine_Gastro_Thyroid_Gout",                     
            "CountVisit_symp_headache",           
            "CountVisit_symp_giddiness",             
            "CountVisit_symp_cold_sores", 
            "CountVisit_symp_rash",      
            "CountVisit_symp_sore_throat",  
            "CountVisit_symp_flu",          
            "CountVisit_symp_cough", 
            "CountVisit_symp_cold",    
            "CountVisit_symp_vomiting", 
            "CountVisit_symp_diarrhoea"
           ]

# %%
select_col = [x for x in all_list if x not in exc_list]

# %%
num_list = [x for x in select_col if x not in cat_list]

# %%
num_list
# Out:
# ['Mem_CountBooking',
#  'AVE_mc_days',
#  'AVE_count_diagnosis',
#  'AVE_count_medication',
#  'AVE_count_repeatmed',
#  'AVE_count_SymID',
#  'age_yr',
#  'WaviedCount_FOLLOW_UP',
#  'WaviedCount_HEALTH_SCREENING_REVIEW',
#  'WaviedCount_OTHERS',
#  'WaviedCount_REFERRAL',
#  'WaviedCount_UNSUITABLE_FOR_TELECONSULT',
#  'WaviedCount_WHITECOAT_FAMILY',
#  'CountVisit_is_mc_issued',
#  'CountVisit_is_referral_letter_issued',
#  'CountVisit_diag_H57',
#  'CountVisit_diag_M23',
#  'CountVisit_diag_T88',
#  'CountVisit_diag_R51',
#  'CountVisit_diag_N94',
#  'CountVisit_diag_G44',
#  'CountVisit_diag_M79',
#  'CountVisit_diag_J02',
#  'CountVisit_diag_J06',
#  'CountVisit_diag_G43',
#  'CountVisit_diag_R21',
#  'CountVisit_diag_M62',
#  'CountVisit_diag_A09',
#  'CountVisit_diag_L30',
#  'CountVisit_diag_T78',
#  'CountVisit_diag_U07',
#  'CountVisit_diag_K29',
#  'CountVisit_diag_B35',
#  'CountVisit_diag_K30',
#  'CountVisit_diag_H81',
#  'CountVisit_diag_N39',
#  'CountVisit_diag_G47',
#  'CountVisit_diag_Z76',
#  'CountVisit_diag_K59',
#  'CountVisit_diag_H10',
#  'CountVisit_diag_R42',
#  'CountVisit_diag_K21',
#  'CountVisit_diag_S90',
#  'CountVisit_diag_R50',
#  'CountVisit_diag_U12',
#  'CountVisit_diag_N92',
#  'CountVisit_diag_M54',
#  'CountVisit_diag_S60',
#  'CountVisit_diag_I10',
#  'CountVisit_diag_L03',
#  'CountVisit_diag_K64',
#  'CountVisit_diag_L98',
#  'CountVisit_diag_B37',
#  'CountVisit_diag_L73',
#  'CountVisit_diag_H00',
#  'CountVisit_diag_N76',
#  'CountVisit_diag_J01',
#  'CountVisit_diag_E78',
#  'CountVisit_diag_L02',
#  'CountVisit_diag_R52',
#  'CountVisit_diag_K12',
#  'CountVisit_diag_K58',
#  'CountVisit_diag_K07',
#  'CountVisit_diag_L70',
#  'CountVisit_diag_Z71',
#  'CountVisit_diag_S63',
#  'CountVisit_diag_M25',
#  'CountVisit_diag_K05',
#  'CountVisit_diag_E03',
#  'CountVisit_diag_L50',
#  'CountVisit_diag_W57',
#  'CountVisit_diag_H93',
#  'CountVisit_diag_H01',
#  'CountVisit_diag_E11',
#  'CountVisit_diag_S13',
#  'CountVisit_diag_F41',
#  'CountVisit_diag_R53',
#  'CountVisit_diag_O91',
#  'CountVisit_diag_H02',
#  'CountVisit_diag_R11',
#  'CountVisit_diag_S93',
#  'CountVisit_diag_L24',
#  'CountVisit_diag_J39',
#  'CountVisit_diag_J32',
#  'CountVisit_diag_B00',
#  'CountVisit_diag_L64',
#  'CountVisit_diag_Y42',
#  'CountVisit_diag_R10',
#  'CountVisit_diag_M10',
#  'CountVisit_diag_M75',
#  'CountVisit_diag_Z02',
#  'CountVisit_diag_J03',
#  'CountVisit_diag_R07',
#  'CountVisit_diag_K13',
#  'CountVisit_diag_Z30',
#  'CountVisit_diag_P39',
#  'CountVisit_diag_R22',
#  'CountVisit_diag_H60',
#  'CountVisit_diag_B02',
#  'CountVisit_diag_L29',
#  'CountVisit_diag_E05',
#  'CountVisit_diag_N64',
#  'CountVisit_diag_R05',
#  'CountVisit_diag_L60',
#  'CountVisit_diag_S80',
#  'CountVisit_diag_M65',
#  'CountVisit_diag_J22',
#  'CountVisit_diag_O21',
#  'CountVisit_diag_M72',
#  'CountVisit_diag_L23',
#  'CountVisit_diag_K52',
#  'CountVisit_chronic_Migraine',
#  'CountVisit_chronic_Gastro-oesophageal_reflux_disease',
#  'CountVisit_chronic_Hypertension',
#  'CountVisit_chronic_Hyperlipidaemia',
#  'CountVisit_chronic_Thyroid',
#  'CountVisit_chronic_Diabetes',
#  'CountVisit_chronic_Gout',
#  'CountVisit_symp_others',
#  'CountVisit_symp_medical_referral',
#  'CountVisit_symp_fever',
#  'CountVisit_symp_N',
#  'CountVisit_symp_discuss_lab_results',
#  'DiffDays_Vist',
#  'Ave_VisitGapDays',
#  'Target_Migraine',
#  'Target_Gastro',
#  'Target_Hypertension',
#  'Target_Hyperlipidaemia',
#  'Target_Thyroid',
#  'Target_Diabetes',
#  'Target_Gout',
#  'ConsultHr_8to10',
#  'ConsultHr_11to13',
#  'ConsultHr_14to17',
#  'ConsultHr_18to21',
#  'ConsultHr_22to23',
#  'Prin1_sym_common',
#  'Prin2_sym_rash',
#  'Prin3_sym_headache',
#  'Prin4_sym_diarrhea']

# %% [markdown]
# ## One Hot encoding

# %%
enc_df = pd.get_dummies(df[cat_list])

# %%
# Drop "gender_Unknown"
drop_oneHot = ["gender_Female", "gender_Male"]

# %%
#[TODO] TO EDIT AND DROP ONE CATEGORY LEVEL FOR ONE-HOT
enc_df = enc_df[drop_oneHot]

# %% [markdown]
# ## Define input and output

# %%
# merge with numerical df for input
X = df[num_list].join(enc_df)

# %%
X.shape
# Out:
# (5000, 143)

# %%
# Define the Target
y = df["Target_Allergic_Dermatitis_Asthma"]  #[TODO] TO EDIT AND DEFINE TARGET LABEL

# %%
# Check input variable names
feature_names = X.columns.tolist()

# %%
# EXPORT PICKLE
# export training Feature List for deployment
PKL_ALL_FEATURE_FILENAME = "model_Grp2_featurelist.pkl"
with open(PKL_ALL_FEATURE_FILENAME, "wb") as file:
    pickle.dump(feature_names, file)

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=42, stratify=y
)

# %%
y.value_counts()
# Out:
# 0    4566
# 1     434
# Name: Target_Allergic_Dermatitis_Asthma, dtype: int64

# %%
y.value_counts(normalize=True)[1] * 100
# Out:
# 8.68

# %% [markdown]
# ## Oversample for Training

# %%
#[TODO] TO INCLUDE IF DATA TARGET CLASS TOO IMBALANCE

# %%
print(f'''Shape of X train without balancing: {X_train.shape}''')
print(f'''% Positive class of X train without balancing = {np.round(y_train.value_counts(normalize=True)[1] * 100, 2)}''')
# Out:
# Shape of X train without balancing: (3500, 143)
# % Positive class of X train without balancing = 8.69

# %%
# OVERSAMPLE_RATIO set here is to oversample the minority class with SMOTE 
# it corresponds to the desired ratio of
# number of samples in minority class over number of samples the majority class after resampling.
if INCL_SMOTE == 1:
    sm = SMOTE(random_state=42, sampling_strategy=OVERSAMPLE_RATIO)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print(f'''Shape of X train after SMOTE: {X_train.shape}''')
    print(f'''% Positive class of X train after SMOTE = {np.round(y_train.value_counts(normalize=True)[1] * 100, 2)}''')
else: 
    print("SMOTE not included.")
# Out:
# SMOTE not included.

# %%
print("SMOTE over-sampling is not done for Test data")
print(f'''Shape of X Test after SMOTE: {X_test.shape}''')
print(f'''% Positive class f X Test before SMOTE = {np.round(y_test.value_counts(normalize=True)[1] * 100, 2)}''')
# Out:
# SMOTE over-sampling is not done for Test data
# Shape of X Test after SMOTE: (1500, 143)
# % Positive class f X Test before SMOTE = 8.67

# %% [markdown]
# Note: Not over-sampling for Test data to maintain data integrity

# %% [markdown]
# ## Remove Outliers

# %% [markdown]
# Isolation Forest, or iForest for short, is a tree-based anomaly detection algorithm.
#
# It is based on modeling the normal data in such a way as to isolate anomalies that are both few in number and different in the feature space.
#
# The method is based on two anomalies’ quantitative properties:
#
# i) they are the minority consisting of fewer instances and
#
# ii) they have attribute-values that are very different from those of normal instances.
# The scikit-learn library provides an implementation of Isolation Forest in the IsolationForest class.

# %%
# identify outliers in the training dataset

if INCL_IFOREST ==1: 
    iso = IsolationForest(contamination=0.1,random_state= 0)
    yhat = iso.fit_predict(X_train)

    # select all rows that are not outliers
    mask = yhat != -1
    X_train, y_train = X_train[mask], y_train[mask]

    print("No of outliers marked: ")
    sum(yhat == -1)
    
    # summarize the shape of the updated training dataset
    print("Shape of processed dataset, X_train vs y_train after removing outliers")
    print(X_train.shape, y_train.shape)

# %% [markdown]
# ## Standardized Data

# %%
sc =  StandardScaler()
# Fit and Transform the training dataset
print("Fit and Transform the training dataset")
X_train = sc.fit_transform(X_train)
# Out:
# Fit and Transform the training dataset

# %%
X_train
# Out:
# array([[-0.58893405, -0.73764835, -0.34397525, ...,  0.05032608,
#          0.83509352, -0.76072989],
#        [ 0.55972528,  0.02035788, -0.34397525, ...,  0.05032608,
#         -1.19747068,  1.31452702],
#        [-0.58893405, -0.73764835, -0.34397525, ...,  0.02922919,
#         -1.19747068,  1.31452702],
#        ...,
#        [-0.58893405,  0.02035788, -0.34397525, ...,  0.05032608,
#         -1.19747068,  1.31452702],
#        [-0.58893405,  0.02035788, -0.34397525, ..., -0.89535284,
#         -1.19747068,  1.31452702],
#        [-0.58893405, -0.73764835, -0.34397525, ...,  0.05032608,
#         -1.19747068,  1.31452702]])

# %%
# Transform the testing dataset
print("Transform the testing dataset (no fitting)")
X_test = sc.transform (X_test)
# Out:
# Transform the testing dataset (no fitting)

# %%
# EXPORT PICKLE
PKL_STANDARDSCALER_FILENAME = "model_Grp2_standardard_scaler.pkl"
with open(PKL_STANDARDSCALER_FILENAME, "wb") as file:
    pickle.dump(sc, file)

# %% [markdown]
# ## Model Selection

# %%
target_names = ['Non-AllergicDermatitisAsthma', 'AllergicDermatitisAsthma']   #Define Target Names

# %% [markdown]
# ### Logistic Model

# %%
LR_model, LR_selectFeature, LR_report_train,  LR_report_test = \
    run_model_N_eval(X_train, X_test, y_train, y_test, model="LR")
# Out:
# Model:  LR
#
# Labels: [0 1]
#
#
#  ####################################################################################################
# For Training Data:
# [[3146   50]
#  [ 222   82]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9341    0.9844    0.9586      3196
#     AllergicDermatitisAsthma     0.6212    0.2697    0.3761       304
#
#                     accuracy                         0.9223      3500
#                    macro avg     0.7776    0.6270    0.6674      3500
#                 weighted avg     0.9069    0.9223    0.9080      3500
#
#
#
#  ####################################################################################################
# For Testing Data:
# [[1337   33]
#  [  93   37]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9350    0.9759    0.9550      1370
#     AllergicDermatitisAsthma     0.5286    0.2846    0.3700       130
#
#                     accuracy                         0.9160      1500
#                    macro avg     0.7318    0.6303    0.6625      1500
#                 weighted avg     0.8997    0.9160    0.9043      1500
#
#
#
#  ####################################################################################################

# %%
# LR Target Report 
LR_frame = { 'Train': LR_report_train["1"], 'Test': LR_report_test["1"] }
LR_report_output= pd.DataFrame(LR_frame)
LR_report_output
# Out:
#                 Train        Test
# precision    0.621212    0.528571
# recall       0.269737    0.284615
# f1-score     0.376147    0.370000
# support    304.000000  130.000000

# %%
# EXPORT PICKLE
# export result
PKL_LR_RESULT_FILENAME = "model_Grp2_result_logistic.pkl"
with open(PKL_LR_RESULT_FILENAME, "wb") as file:
    pickle.dump(LR_report_output, file)

# %% [markdown]
# ### Support Vector Machine (Linear)

# %%
SVM_model, SVM_selectFeature, SVM_report_train, SVM_report_test = run_model_N_eval(X_train, X_test, y_train, y_test, "SVM")
# Out:
# Model:  SVM
#
# Labels: [0 1]
#
#
#  ####################################################################################################
# For Training Data:
# [[3193    3]
#  [ 279   25]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9196    0.9991    0.9577      3196
#     AllergicDermatitisAsthma     0.8929    0.0822    0.1506       304
#
#                     accuracy                         0.9194      3500
#                    macro avg     0.9062    0.5406    0.5542      3500
#                 weighted avg     0.9173    0.9194    0.8876      3500
#
#
#
#  ####################################################################################################
# For Testing Data:
# [[1363    7]
#  [ 119   11]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9197    0.9949    0.9558      1370
#     AllergicDermatitisAsthma     0.6111    0.0846    0.1486       130
#
#                     accuracy                         0.9160      1500
#                    macro avg     0.7654    0.5398    0.5522      1500
#                 weighted avg     0.8930    0.9160    0.8859      1500
#
#
#
#  ####################################################################################################

# %%
# SVM Target Report 
SVM_frame = { 'Train': SVM_report_train["1"], 'Test': SVM_report_test["1"] }
SVM_report_output= pd.DataFrame(SVM_frame)
SVM_report_output
# Out:
#                 Train        Test
# precision    0.892857    0.611111
# recall       0.082237    0.084615
# f1-score     0.150602    0.148649
# support    304.000000  130.000000

# %%
# EXPORT PICKLE
# export result
PKL_SVM_RESULT_FILENAME = "model_Grp2_result_svm.pkl"
with open(PKL_SVM_RESULT_FILENAME, "wb") as file:
    pickle.dump(SVM_report_output, file)

# %% [markdown]
# ### Support Vector Machine (Non-Linear)

# %%
NLSVM_model, NLSVM_selectFeature, NLSVM_report_train, NLSVM_report_test = run_model_N_eval(X_train, X_test, y_train, y_test, "NLSVM")
# Out:
# Model:  NLSVM
#
# Labels: [0 1]
#
#
#  ####################################################################################################
# For Training Data:
# [[3194    2]
#  [ 204  100]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9400    0.9994    0.9688      3196
#     AllergicDermatitisAsthma     0.9804    0.3289    0.4926       304
#
#                     accuracy                         0.9411      3500
#                    macro avg     0.9602    0.6642    0.7307      3500
#                 weighted avg     0.9435    0.9411    0.9274      3500
#
#
#
#  ####################################################################################################
# For Testing Data:
# [[1366    4]
#  [ 119   11]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9199    0.9971    0.9569      1370
#     AllergicDermatitisAsthma     0.7333    0.0846    0.1517       130
#
#                     accuracy                         0.9180      1500
#                    macro avg     0.8266    0.5408    0.5543      1500
#                 weighted avg     0.9037    0.9180    0.8871      1500
#
#
#
#  ####################################################################################################

# %%
# NLSVM Target Report 
NLSVM_frame = { 'Train': NLSVM_report_train["1"], 'Test': NLSVM_report_test["1"] }
NLSVM_report_output= pd.DataFrame(NLSVM_frame)
NLSVM_report_output
# Out:
#                 Train        Test
# precision    0.980392    0.733333
# recall       0.328947    0.084615
# f1-score     0.492611    0.151724
# support    304.000000  130.000000

# %%
# EXPORT PICKLE
# export result
PKL_NLSVM_RESULT_FILENAME = "model_Grp2_result_nonlinearsvm.pkl"
with open(PKL_NLSVM_RESULT_FILENAME, "wb") as file:
    pickle.dump(NLSVM_report_output, file)

# %% [markdown]
# ### Random Forest

# %%
RF_model, RF_selectFeature, RF_report_train, RF_report_test = run_model_N_eval(X_train, X_test, y_train, y_test, "RF")
# Out:
# Model:  RF
#
# Labels: [0 1]
#
#
#  ####################################################################################################
# For Training Data:
# [[3194    2]
#  [ 259   45]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9250    0.9994    0.9607      3196
#     AllergicDermatitisAsthma     0.9574    0.1480    0.2564       304
#
#                     accuracy                         0.9254      3500
#                    macro avg     0.9412    0.5737    0.6086      3500
#                 weighted avg     0.9278    0.9254    0.8996      3500
#
#
#
#  ####################################################################################################
# For Testing Data:
# [[1366    4]
#  [ 119   11]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9199    0.9971    0.9569      1370
#     AllergicDermatitisAsthma     0.7333    0.0846    0.1517       130
#
#                     accuracy                         0.9180      1500
#                    macro avg     0.8266    0.5408    0.5543      1500
#                 weighted avg     0.9037    0.9180    0.8871      1500
#
#
#
#  ####################################################################################################

# %%
# RF Target Report 
RF_frame = { 'Train': RF_report_train["1"], 'Test': RF_report_test["1"] }
RF_report_output= pd.DataFrame(RF_frame)
RF_report_output
# Out:
#                 Train        Test
# precision    0.957447    0.733333
# recall       0.148026    0.084615
# f1-score     0.256410    0.151724
# support    304.000000  130.000000

# %%
# EXPORT PICKLE
# export result
PKL_RF_RESULT_FILENAME = "model_Grp2_result_randomforest.pkl"
with open(PKL_RF_RESULT_FILENAME, "wb") as file:
    pickle.dump(RF_report_output, file)

# %% [markdown]
# ### XGBoost

# %%
XGB_model, XGB_selectFeature,  XGB_report_train, XGB_report_test = run_model_N_eval(X_train, X_test, y_train, y_test, "XGB")
# Out:
# [22:34:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Model:  XGB
#
# Labels: [0 1]
#
#
#  ####################################################################################################
# For Training Data:
# [[3183   13]
#  [ 232   72]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9321    0.9959    0.9629      3196
#     AllergicDermatitisAsthma     0.8471    0.2368    0.3702       304
#
#                     accuracy                         0.9300      3500
#                    macro avg     0.8896    0.6164    0.6666      3500
#                 weighted avg     0.9247    0.9300    0.9115      3500
#
#
#
#  ####################################################################################################
# For Testing Data:
# [[1352   18]
#  [ 103   27]]
#                               precision    recall  f1-score   support
#
# Non-AllergicDermatitisAsthma     0.9292    0.9869    0.9572      1370
#     AllergicDermatitisAsthma     0.6000    0.2077    0.3086       130
#
#                     accuracy                         0.9193      1500
#                    macro avg     0.7646    0.5973    0.6329      1500
#                 weighted avg     0.9007    0.9193    0.9010      1500
#
#
#
#  ####################################################################################################

# %%
# XGB Target Report 
XGB_frame = { 'Train': XGB_report_train["1"], 'Test': XGB_report_test["1"] }
XGB_report_output= pd.DataFrame(XGB_frame)
XGB_report_output
# Out:
#                 Train        Test
# precision    0.847059    0.600000
# recall       0.236842    0.207692
# f1-score     0.370180    0.308571
# support    304.000000  130.000000

# %%
# EXPORT PICKLE
# export result
PKL_XGB_RESULT_FILENAME = "model_Grp2_result_xgb.pkl"
with open(PKL_XGB_RESULT_FILENAME, "wb") as file:
    pickle.dump(XGB_report_output, file)

# %% [markdown]
# ## Feature Selected

# %%
# EXPORT PICKLE
PKL_SELECT_MODEL_FILENAME = "model_Grp2_selectfeature.pkl"
with open(PKL_SELECT_MODEL_FILENAME, "wb") as file:
    pickle.dump(LR_selectFeature, file)

# %%
X_newTest_LR = LR_selectFeature.transform(X_test)
X_newTrain_LR = LR_selectFeature.transform(X_train)
feature_idx_LR = LR_selectFeature.get_support()
final_selectList_LR = list(compress(feature_names, feature_idx_LR))
len(final_selectList_LR)
# Out:
# 49

# %%
final_selectList_LR
# Out:
# ['Mem_CountBooking',
#  'AVE_mc_days',
#  'AVE_count_diagnosis',
#  'AVE_count_medication',
#  'CountVisit_is_mc_issued',
#  'CountVisit_diag_T88',
#  'CountVisit_diag_R51',
#  'CountVisit_diag_N94',
#  'CountVisit_diag_M79',
#  'CountVisit_diag_J02',
#  'CountVisit_diag_J06',
#  'CountVisit_diag_R21',
#  'CountVisit_diag_M62',
#  'CountVisit_diag_A09',
#  'CountVisit_diag_L30',
#  'CountVisit_diag_U07',
#  'CountVisit_diag_K29',
#  'CountVisit_diag_K30',
#  'CountVisit_diag_H81',
#  'CountVisit_diag_N39',
#  'CountVisit_diag_K59',
#  'CountVisit_diag_R50',
#  'CountVisit_diag_M54',
#  'CountVisit_diag_I10',
#  'CountVisit_diag_B37',
#  'CountVisit_diag_E78',
#  'CountVisit_diag_S63',
#  'CountVisit_diag_L50',
#  'CountVisit_diag_W57',
#  'CountVisit_diag_L24',
#  'CountVisit_diag_B00',
#  'CountVisit_diag_Y42',
#  'CountVisit_diag_M75',
#  'CountVisit_diag_J03',
#  'CountVisit_diag_L60',
#  'CountVisit_diag_M72',
#  'CountVisit_chronic_Hypertension',
#  'CountVisit_chronic_Hyperlipidaemia',
#  'CountVisit_chronic_Thyroid',
#  'DiffDays_Vist',
#  'Target_Diabetes',
#  'ConsultHr_8to10',
#  'ConsultHr_11to13',
#  'ConsultHr_14to17',
#  'ConsultHr_18to21',
#  'ConsultHr_22to23',
#  'Prin1_sym_common',
#  'Prin3_sym_headache',
#  'Prin4_sym_diarrhea']

# %%
X_newTest_SVM = SVM_selectFeature.transform(X_test)
X_newTrain_SVM = SVM_selectFeature.transform(X_train)
feature_idx_SVM = SVM_selectFeature.get_support()
final_selectList_SVM = list(compress(feature_names, feature_idx_SVM))
len(final_selectList_SVM)
# Out:
# 49

# %%
X_newTest_NLSVM = NLSVM_selectFeature.transform(X_test)
X_newTrain_NLSVM = NLSVM_selectFeature.transform(X_train)
feature_idx_NLSVM = NLSVM_selectFeature.get_support()
final_selectList_NLSVM = list(compress(feature_names, feature_idx_NLSVM))
len(final_selectList_NLSVM)
# Out:
# 49

# %%
X_newTest_RF = RF_selectFeature.transform(X_test)
X_newTrain_RF = RF_selectFeature.transform(X_train)
feature_idx_RF = RF_selectFeature.get_support()
final_selectList_RF = list(compress(feature_names, feature_idx_RF))
len(final_selectList_RF)
# Out:
# 49

# %%
X_newTest_XGB = XGB_selectFeature.transform(X_test)
X_newTrain_XGB = XGB_selectFeature.transform(X_train)
feature_idx_XGB = XGB_selectFeature.get_support()
final_selectList_XGB = list(compress(feature_names, feature_idx_XGB))
len(final_selectList_XGB)
# Out:
# 49

# %% [markdown]
# ## ROC

# %%
# EXPORT PICKLE
#Export LR_model for deployment
PKL_LR_MODEL_FILENAME = "model_Grp2_logistic.pkl"
with open(PKL_LR_MODEL_FILENAME, "wb") as file:
    pickle.dump(LR_model, file)

# %%
# EXPORT PICKLE
#Export SVM_model for deployment
PKL_SVM_MODEL_FILENAME = "model_Grp2_svm.pkl"
with open(PKL_SVM_MODEL_FILENAME, "wb") as file:
    pickle.dump(SVM_model, file)

# %%
# EXPORT PICKLE
#Export Non-linear SVM_model for deployment
PKL_NLSVM_MODEL_FILENAME = "model_Grp2_nonlinear_svm.pkl"
with open(PKL_NLSVM_MODEL_FILENAME, "wb") as file:
    pickle.dump(NLSVM_model, file)

# %%
# EXPORT PICKLE
#Export RF_model for deployment
PKL_RF_MODEL_FILENAME = "model_Grp2_randomforest.pkl"
with open(PKL_RF_MODEL_FILENAME, "wb") as file:
    pickle.dump(RF_model, file)

# %%
# EXPORT PICKLE
#Export XGB_model for deployment
PKL_XGB_MODEL_FILENAME = "model_Grp2_xgb.pkl"
with open(PKL_XGB_MODEL_FILENAME, "wb") as file:
    pickle.dump(XGB_model, file)

# %%
lr_probs = LR_model.predict_proba(X_newTest_LR)[:,1]
lr_auc = roc_auc_score(y_test, lr_probs, average=None)
lr_auc = round(lr_auc,5)
lr_auc
# Out:
# 0.80861

# %%
svm_probs = SVM_model.predict_proba(X_newTest_SVM)[:,1]
svm_auc = roc_auc_score(y_test, svm_probs, average=None)
svm_auc = round(svm_auc,5)
svm_auc
# Out:
# 0.8149

# %%
nlsvm_probs = NLSVM_model.predict_proba(X_newTest_NLSVM)[:,1]
nlsvm_auc = roc_auc_score(y_test, nlsvm_probs, average=None)
nlsvm_auc = round(nlsvm_auc, 5)
svm_auc
# Out:
# 0.8149

# %%
rf_probs = RF_model.predict_proba(X_newTest_RF)[:,1]
rf_auc = roc_auc_score(y_test, rf_probs, average=None)
rf_auc = round(rf_auc, 5)
rf_auc
# Out:
# 0.84873

# %%
xgb_probs = XGB_model.predict_proba(X_newTest_XGB)[:,1]
xgb_auc = roc_auc_score(y_test, xgb_probs, average=None)
xgb_auc = round(xgb_auc, 5)
xgb_auc
# Out:
# 0.85818

# %%
# %matplotlib inline
plt.figure(figsize=(10,8))
ax = plt.gca()
LR_disp = RocCurveDisplay.from_estimator(LR_model, X_newTest_LR, y_test, ax=ax, alpha=0.8)
SVM_disp = RocCurveDisplay.from_estimator(SVM_model, X_newTest_SVM, y_test, ax=ax, alpha=0.8)
NLSVM_disp = RocCurveDisplay.from_estimator(NLSVM_model, X_newTest_NLSVM, y_test, ax=ax, alpha=0.8)
RF_disp = RocCurveDisplay.from_estimator(RF_model, X_newTest_RF, y_test, ax=ax, alpha=0.8)
XGB_disp = RocCurveDisplay.from_estimator(XGB_model, X_newTest_XGB, y_test, ax=ax, alpha=0.8)
plt.title("ROC Evaluation of Different Model, using Testing Data")
plt.show()

# %% [markdown]
# ## Model Explanability

# %% [markdown]
# ### Random Forest

# %%
if RUN_SHAP == 1:
    # [TODO] To choose the final model and correct selected features selected
    MODEL_SELECTED = RF_model
    X_TRAIN = X_newTrain_RF
    X_TEST = X_newTest_RF
    FINAL_LIST = final_selectList_RF
    
    explainer = shap.TreeExplainer(MODEL_SELECTED)
    
    shap_values = explainer.shap_values(X_TRAIN)
    
    #Summarize the effect of all the features on Target
    # To make the interpretation easier
    print("EXPLAIN THE EFFECT OF FEATURES ON TARGET CLASS USING SHAP VALUES")
    shap.summary_plot(shap_values[1], X_TRAIN, feature_names=FINAL_LIST)
# Out:
# EXPLAIN THE EFFECT OF FEATURES ON TARGET CLASS USING SHAP VALUES

# %% [markdown]
# @end
